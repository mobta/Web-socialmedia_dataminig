# %% [markdown]
# ## Advanced twitter mining + MongoDB

# %% [markdown]
# This notebook is a collection of examples reproduced from the book : *Mining the Social Web*. In addition, an implementation of a function to Render JSON into collapsible HTML, and a short introduction to MongoDB

# %%
import twitter
import json
import sys
import time
from urllib.error import URLError
from http.client import BadStatusLine
from collections import Counter

# %%
# Authentification
def oauth_login():
    
    CONSUMER_KEY = ''
    CONSUMER_SECRET = ''
    OAUTH_TOKEN = ''
    OAUTH_TOKEN_SECRET = ''
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

twitter_api = oauth_login()    

twitter_api

# %%
# Explore trends
def twitter_trends(twitter_api, woe_id):
    return twitter_api.trends.place(_id=woe_id)

twitter_api = oauth_login()

WORLD_WOE_ID = 1
world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
print (json.dumps(world_trends, indent=1))

US_WOE_ID = 23424977
us_trends = twitter_trends(twitter_api, US_WOE_ID)
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "created_at": "2018-01-23T03:08:44Z",
#   "as_of": "2018-01-23T03:10:16Z",
#   "trends": [
#    {
#     "name": "#RAW25",
#     "url": "http://twitter.com/search?q=%23RAW25",
#     "promoted_content": null,
#     "tweet_volume": 394866,
#     "query": "%23RAW25"
#    },
#    {
#     "name": "#BBB18",
#     "url": "http://twitter.com/search?q=%23BBB18",
#     "promoted_content": null,
#     "tweet_volume": 212047,
#     "query": "%23BBB18"
#    },
#    {
#     "name": "#OTGala12",
#     "url": "http://twitter.com/search?q=%23OTGala12",
#     "promoted_content": null,
#     "tweet_volume": 474635,
#     "query": "%23OTGala12"
#    },
#    {
#     "name": "#TheBachelor",
#     "url": "http://twitter.com/search?q=%23TheBachelor",
#     "promoted_content": null,
#     "tweet_volume": 48952,
#     "query": "%23TheBachelor"
#    },
#    {
#     "name": "Estrelas",
#     "url": "http://twitter.com/search?q=Estrelas",
#     "promoted_content": null,
#     "tweet_volume": 140233,
#     "query": "Estrelas"
#    },
#    {
#     "name": "#LHHMIA",
#     "url": "http://twitter.com/search?q=%23LHHMIA",
#     "promoted_content": null,
#     "tweet_volume": 17412,
#     "query": "%23LHHMIA"
#    },
#    {
#     "name": "Sisu",
#     "url": "http://twitter.com/search?q=Sisu",
#     "promoted_content": null,
#     "tweet_volume": 24816,
#     "query": "Sisu"
#    },
#    {
#     "name": "\u8349\u6d25\u767d\u6839\u5c71",
#     "url": "http://twitter.com/search?q=%E8%8D%89%E6%B4%A5%E7%99%BD%E6%A0%B9%E5%B1%B1",
#     "promoted_content": null,
#     "tweet_volume": 34281,
#     "query": "%E8%8D%89%E6%B4%A5%E7%99%BD%E6%A0%B9%E5%B1%B1"
#    },
#    {
#     "name": "Torrie Wilson",
#     "url": "http://twitter.com/search?q=%22Torrie+Wilson%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Torrie+Wilson%22"
#    },
#    {
#     "name": "Jason Jordan",
#     "url": "http://twitter.com/search?q=%22Jason+Jordan%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Jason+Jordan%22"
#    },
#    {
#     "name": "Hazel",
#     "url": "http://twitter.com/search?q=Hazel",
#     "promoted_content": null,
#     "tweet_volume": 38604,
#     "query": "Hazel"
#    },
#    {
#     "name": "Kelly Kelly",
#     "url": "http://twitter.com/search?q=%22Kelly+Kelly%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Kelly+Kelly%22"
#    },
#    {
#     "name": "Simona",
#     "url": "http://twitter.com/search?q=Simona",
#     "promoted_content": null,
#     "tweet_volume": 130007,
#     "query": "Simona"
#    },
#    {
#     "name": "Polenta",
#     "url": "http://twitter.com/search?q=Polenta",
#     "promoted_content": null,
#     "tweet_volume": 11789,
#     "query": "Polenta"
#    },
#    {
#     "name": "\uc870\uc724\uc120",
#     "url": "http://twitter.com/search?q=%EC%A1%B0%EC%9C%A4%EC%84%A0",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%EC%A1%B0%EC%9C%A4%EC%84%A0"
#    },
#    {
#     "name": "Chris Jericho",
#     "url": "http://twitter.com/search?q=%22Chris+Jericho%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Chris+Jericho%22"
#    },
#    {
#     "name": "Neil Diamond",
#     "url": "http://twitter.com/search?q=%22Neil+Diamond%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Neil+Diamond%22"
#    },
#    {
#     "name": "ACEDE",
#     "url": "http://twitter.com/search?q=ACEDE",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "ACEDE"
#    },
#    {
#     "name": "Swansea",
#     "url": "http://twitter.com/search?q=Swansea",
#     "promoted_content": null,
#     "tweet_volume": 124955,
#     "query": "Swansea"
#    },
#    {
#     "name": "Aran",
#     "url": "http://twitter.com/search?q=Aran",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "Aran"
#    },
#    {
#     "name": "Lloyd Pope",
#     "url": "http://twitter.com/search?q=%22Lloyd+Pope%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Lloyd+Pope%22"
#    },
#    {
#     "name": "Oriente Petrolero",
#     "url": "http://twitter.com/search?q=%22Oriente+Petrolero%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Oriente+Petrolero%22"
#    },
#    {
#     "name": "John Green",
#     "url": "http://twitter.com/search?q=%22John+Green%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22John+Green%22"
#    },
#    {
#     "name": "#PorqueSoyMexicano",
#     "url": "http://twitter.com/search?q=%23PorqueSoyMexicano",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23PorqueSoyMexicano"
#    },
#    {
#     "name": "#DeseoOculto",
#     "url": "http://twitter.com/search?q=%23DeseoOculto",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23DeseoOculto"
#    },
#    {
#     "name": "#isola",
#     "url": "http://twitter.com/search?q=%23isola",
#     "promoted_content": null,
#     "tweet_volume": 117241,
#     "query": "%23isola"
#    },
#    {
#     "name": "#\u0634\u0647\u0627\u062f\u062a\u0646\u0627_\u0628\u0643\u0627\u0644\u0648\u0631\u064a\u0648\u0633_\u0648\u0639\u0627\u0637\u0644\u064a\u0646",
#     "url": "http://twitter.com/search?q=%23%D8%B4%D9%87%D8%A7%D8%AF%D8%AA%D9%86%D8%A7_%D8%A8%D9%83%D8%A7%D9%84%D9%88%D8%B1%D9%8A%D9%88%D8%B3_%D9%88%D8%B9%D8%A7%D8%B7%D9%84%D9%8A%D9%86",
#     "promoted_content": null,
#     "tweet_volume": 25643,
#     "query": "%23%D8%B4%D9%87%D8%A7%D8%AF%D8%AA%D9%86%D8%A7_%D8%A8%D9%83%D8%A7%D9%84%D9%88%D8%B1%D9%8A%D9%88%D8%B3_%D9%88%D8%B9%D8%A7%D8%B7%D9%84%D9%8A%D9%86"
#    },
#    {
#     "name": "#PumpRules",
#     "url": "http://twitter.com/search?q=%23PumpRules",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23PumpRules"
#    },
#    {
#     "name": "#OOutroLadoParaiso",
#     "url": "http://twitter.com/search?q=%23OOutroLadoParaiso",
#     "promoted_content": null,
#     "tweet_volume": 15404,
#     "query": "%23OOutroLadoParaiso"
#    },
#    {
#     "name": "#aLibertina",
#     "url": "http://twitter.com/search?q=%23aLibertina",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23aLibertina"
#    },
#    {
#     "name": "#TercaDetremuraSDV",
#     "url": "http://twitter.com/search?q=%23TercaDetremuraSDV",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TercaDetremuraSDV"
#    },
#    {
#     "name": "#LunesIntratable",
#     "url": "http://twitter.com/search?q=%23LunesIntratable",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23LunesIntratable"
#    },
#    {
#     "name": "#AdiosHaiti",
#     "url": "http://twitter.com/search?q=%23AdiosHaiti",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23AdiosHaiti"
#    },
#    {
#     "name": "#EnElGymNuncaFalta",
#     "url": "http://twitter.com/search?q=%23EnElGymNuncaFalta",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23EnElGymNuncaFalta"
#    },
#    {
#     "name": "#ChileLindo",
#     "url": "http://twitter.com/search?q=%23ChileLindo",
#     "promoted_content": null,
#     "tweet_volume": 31992,
#     "query": "%23ChileLindo"
#    },
#    {
#     "name": "#TheAlienist",
#     "url": "http://twitter.com/search?q=%23TheAlienist",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TheAlienist"
#    },
#    {
#     "name": "#CorderoAlPaloMV",
#     "url": "http://twitter.com/search?q=%23CorderoAlPaloMV",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23CorderoAlPaloMV"
#    },
#    {
#     "name": "#UnlikelyHomeworkExcuses",
#     "url": "http://twitter.com/search?q=%23UnlikelyHomeworkExcuses",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23UnlikelyHomeworkExcuses"
#    },
#    {
#     "name": "#\u0628\u0646_\u0634\u0631\u0642\u064a_\u0647\u0644\u0627\u0644\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A8%D9%86_%D8%B4%D8%B1%D9%82%D9%8A_%D9%87%D9%84%D8%A7%D9%84%D9%8A",
#     "promoted_content": null,
#     "tweet_volume": 101887,
#     "query": "%23%D8%A8%D9%86_%D8%B4%D8%B1%D9%82%D9%8A_%D9%87%D9%84%D8%A7%D9%84%D9%8A"
#    },
#    {
#     "name": "#COAC2018P14",
#     "url": "http://twitter.com/search?q=%23COAC2018P14",
#     "promoted_content": null,
#     "tweet_volume": 12321,
#     "query": "%23COAC2018P14"
#    },
#    {
#     "name": "#UEVenezuelaSeRespeta",
#     "url": "http://twitter.com/search?q=%23UEVenezuelaSeRespeta",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23UEVenezuelaSeRespeta"
#    },
#    {
#     "name": "#DiosdadoNarcoLLORON",
#     "url": "http://twitter.com/search?q=%23DiosdadoNarcoLLORON",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23DiosdadoNarcoLLORON"
#    },
#    {
#     "name": "#ReasonsToStayInside",
#     "url": "http://twitter.com/search?q=%23ReasonsToStayInside",
#     "promoted_content": null,
#     "tweet_volume": 10187,
#     "query": "%23ReasonsToStayInside"
#    },
#    {
#     "name": "#FFCsegueFFC",
#     "url": "http://twitter.com/search?q=%23FFCsegueFFC",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23FFCsegueFFC"
#    },
#    {
#     "name": "#CondenaTRF4",
#     "url": "http://twitter.com/search?q=%23CondenaTRF4",
#     "promoted_content": null,
#     "tweet_volume": 86238,
#     "query": "%23CondenaTRF4"
#    }
#   ],
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "created_at": "2018-01-23T03:08:44Z",
#   "as_of": "2018-01-23T03:10:16Z",
#   "trends": [
#    {
#     "name": "#RAW25",
#     "url": "http://twitter.com/search?q=%23RAW25",
#     "promoted_content": null,
#     "tweet_volume": 394866,
#     "query": "%23RAW25"
#    },
#    {
#     "name": "#TheBachelor",
#     "url": "http://twitter.com/search?q=%23TheBachelor",
#     "promoted_content": null,
#     "tweet_volume": 48952,
#     "query": "%23TheBachelor"
#    },
#    {
#     "name": "#LHHMIA",
#     "url": "http://twitter.com/search?q=%23LHHMIA",
#     "promoted_content": null,
#     "tweet_volume": 17412,
#     "query": "%23LHHMIA"
#    },
#    {
#     "name": "#PumpRules",
#     "url": "http://twitter.com/search?q=%23PumpRules",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23PumpRules"
#    },
#    {
#     "name": "Torrie Wilson",
#     "url": "http://twitter.com/search?q=%22Torrie+Wilson%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Torrie+Wilson%22"
#    },
#    {
#     "name": "Jason Jordan",
#     "url": "http://twitter.com/search?q=%22Jason+Jordan%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Jason+Jordan%22"
#    },
#    {
#     "name": "Matt Hardy",
#     "url": "http://twitter.com/search?q=%22Matt+Hardy%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Matt+Hardy%22"
#    },
#    {
#     "name": "#TheAlienist",
#     "url": "http://twitter.com/search?q=%23TheAlienist",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TheAlienist"
#    },
#    {
#     "name": "Neil Diamond",
#     "url": "http://twitter.com/search?q=%22Neil+Diamond%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Neil+Diamond%22"
#    },
#    {
#     "name": "Buzz Williams",
#     "url": "http://twitter.com/search?q=%22Buzz+Williams%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Buzz+Williams%22"
#    },
#    {
#     "name": "Austin Jackson",
#     "url": "http://twitter.com/search?q=%22Austin+Jackson%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Austin+Jackson%22"
#    },
#    {
#     "name": "Juwan Morgan",
#     "url": "http://twitter.com/search?q=%22Juwan+Morgan%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Juwan+Morgan%22"
#    },
#    {
#     "name": "James Palmer",
#     "url": "http://twitter.com/search?q=%22James+Palmer%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22James+Palmer%22"
#    },
#    {
#     "name": "Alexa Bliss",
#     "url": "http://twitter.com/search?q=%22Alexa+Bliss%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Alexa+Bliss%22"
#    },
#    {
#     "name": "Miles Bridges",
#     "url": "http://twitter.com/search?q=%22Miles+Bridges%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Miles+Bridges%22"
#    },
#    {
#     "name": "Bill Cosby",
#     "url": "http://twitter.com/search?q=%22Bill+Cosby%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Bill+Cosby%22"
#    },
#    {
#     "name": "Maryse",
#     "url": "http://twitter.com/search?q=Maryse",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "Maryse"
#    },
#    {
#     "name": "McCabe",
#     "url": "http://twitter.com/search?q=McCabe",
#     "promoted_content": null,
#     "tweet_volume": 33285,
#     "query": "McCabe"
#    },
#    {
#     "name": "Jamie Dixon",
#     "url": "http://twitter.com/search?q=%22Jamie+Dixon%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Jamie+Dixon%22"
#    },
#    {
#     "name": "Ryan Anderson",
#     "url": "http://twitter.com/search?q=%22Ryan+Anderson%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Ryan+Anderson%22"
#    },
#    {
#     "name": "Nia Jax",
#     "url": "http://twitter.com/search?q=%22Nia+Jax%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Nia+Jax%22"
#    },
#    {
#     "name": "#UnlikelyHomeworkExcuses",
#     "url": "http://twitter.com/search?q=%23UnlikelyHomeworkExcuses",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23UnlikelyHomeworkExcuses"
#    },
#    {
#     "name": "#ReasonsToStayInside",
#     "url": "http://twitter.com/search?q=%23ReasonsToStayInside",
#     "promoted_content": null,
#     "tweet_volume": 10187,
#     "query": "%23ReasonsToStayInside"
#    },
#    {
#     "name": "#TeenMomOG",
#     "url": "http://twitter.com/search?q=%23TeenMomOG",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TeenMomOG"
#    },
#    {
#     "name": "#SchumerSellout",
#     "url": "http://twitter.com/search?q=%23SchumerSellout",
#     "promoted_content": null,
#     "tweet_volume": 18982,
#     "query": "%23SchumerSellout"
#    },
#    {
#     "name": "#Lucifer",
#     "url": "http://twitter.com/search?q=%23Lucifer",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23Lucifer"
#    },
#    {
#     "name": "#hogfbchat",
#     "url": "http://twitter.com/search?q=%23hogfbchat",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23hogfbchat"
#    },
#    {
#     "name": "#WizMavs",
#     "url": "http://twitter.com/search?q=%23WizMavs",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23WizMavs"
#    }
#   ],
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
import uuid
from IPython.display import display_javascript, display_html, display

# This is a function to Render JSON into collapsible HTML, check the reference: http://caldwell.github.io/renderjson/
class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json
        self.uuid = str(uuid.uuid4())

    def _ipython_display_(self):
        display_html('<div id="{}" style="height: 100px; width:100%;"></div>'.format(self.uuid),
            raw=True
        )
        display_javascript("""
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
          document.getElementById('%s').appendChild(renderjson(%s))
        });
        """ % (self.uuid, self.json_str), raw=True)

# %%
# Tweets search
def twitter_search(twitter_api, q, max_results=200, **kw):
    
    search_results = twitter_api.search.tweets(q=q, count=100, **kw)
    
    statuses = search_results['statuses']
    
    # Iterate through batches of results by following the cursor until we
    # reach the desired number of results, keeping in mind that OAuth users
    # can "only" make 180 search queries per 15-minute interval
    
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError as e: # No more results when next_results doesn't exist
            break
            
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                        for kv in next_results[1:].split("&") ])
        
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        
        if len(statuses) > max_results: 
            break
            
    return statuses

twitter_api = oauth_login()

q = "Obama"
results = twitter_search(twitter_api, q, max_results=10)
        
RenderJSON(results[0])
# Out:
# <div id="73e6e69c-9c5d-4ace-b6e1-35369165b294" style="height: 100px; width:100%;"></div>

# %%
def twitter_trends(twitter_api, woe_id):
    return twitter_api.trends.place(_id=woe_id)

twitter_api = oauth_login()

WORLD_WOE_ID = 1
world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
RenderJSON(world_trends[0])
# Out:
# <div id="88bd8d21-413c-4d6f-811d-c565c245a028" style="height: 100px; width:100%;"></div>

# %%
US_WOE_ID = 23424977
us_trends = twitter_trends(twitter_api, US_WOE_ID)
RenderJSON(us_trends[0])
# Out:
# <div id="7e49ad76-64ce-4ceb-8b60-1ca77769c864" style="height: 100px; width:100%;"></div>

# %%
# use partial for better function call
from functools import partial

pp = partial(json.dumps, indent=1)

twitter_world_trends = partial(twitter_trends, twitter_api, WORLD_WOE_ID)

print (pp(twitter_world_trends()))

authenticated_twitter_search = partial(twitter_search, twitter_api)
results = authenticated_twitter_search("iPhone")
print (pp(results[0]))

authenticated_iphone_twitter_search = partial(authenticated_twitter_search, "iPhone")
results = authenticated_iphone_twitter_search()
print (pp(results[0]))
# Out:
# [
#  {
#   "created_at": "2018-01-23T03:03:50Z",
#   "as_of": "2018-01-23T03:10:25Z",
#   "trends": [
#    {
#     "name": "#RAW25",
#     "url": "http://twitter.com/search?q=%23RAW25",
#     "promoted_content": null,
#     "tweet_volume": 382547,
#     "query": "%23RAW25"
#    },
#    {
#     "name": "#BBB18",
#     "url": "http://twitter.com/search?q=%23BBB18",
#     "promoted_content": null,
#     "tweet_volume": 211226,
#     "query": "%23BBB18"
#    },
#    {
#     "name": "#OTGala12",
#     "url": "http://twitter.com/search?q=%23OTGala12",
#     "promoted_content": null,
#     "tweet_volume": 474467,
#     "query": "%23OTGala12"
#    },
#    {
#     "name": "#TheBachelor",
#     "url": "http://twitter.com/search?q=%23TheBachelor",
#     "promoted_content": null,
#     "tweet_volume": 47803,
#     "query": "%23TheBachelor"
#    },
#    {
#     "name": "#LHHMIA",
#     "url": "http://twitter.com/search?q=%23LHHMIA",
#     "promoted_content": null,
#     "tweet_volume": 16898,
#     "query": "%23LHHMIA"
#    },
#    {
#     "name": "Sisu",
#     "url": "http://twitter.com/search?q=Sisu",
#     "promoted_content": null,
#     "tweet_volume": 23678,
#     "query": "Sisu"
#    },
#    {
#     "name": "\u8349\u6d25\u767d\u6839\u5c71",
#     "url": "http://twitter.com/search?q=%E8%8D%89%E6%B4%A5%E7%99%BD%E6%A0%B9%E5%B1%B1",
#     "promoted_content": null,
#     "tweet_volume": 31085,
#     "query": "%E8%8D%89%E6%B4%A5%E7%99%BD%E6%A0%B9%E5%B1%B1"
#    },
#    {
#     "name": "Torrie Wilson",
#     "url": "http://twitter.com/search?q=%22Torrie+Wilson%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Torrie+Wilson%22"
#    },
#    {
#     "name": "Jason Jordan",
#     "url": "http://twitter.com/search?q=%22Jason+Jordan%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Jason+Jordan%22"
#    },
#    {
#     "name": "Hazel",
#     "url": "http://twitter.com/search?q=Hazel",
#     "promoted_content": null,
#     "tweet_volume": 37106,
#     "query": "Hazel"
#    },
#    {
#     "name": "Kelly Kelly",
#     "url": "http://twitter.com/search?q=%22Kelly+Kelly%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Kelly+Kelly%22"
#    },
#    {
#     "name": "Simona",
#     "url": "http://twitter.com/search?q=Simona",
#     "promoted_content": null,
#     "tweet_volume": 129476,
#     "query": "Simona"
#    },
#    {
#     "name": "Polenta",
#     "url": "http://twitter.com/search?q=Polenta",
#     "promoted_content": null,
#     "tweet_volume": 11431,
#     "query": "Polenta"
#    },
#    {
#     "name": "\uc870\uc724\uc120",
#     "url": "http://twitter.com/search?q=%EC%A1%B0%EC%9C%A4%EC%84%A0",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%EC%A1%B0%EC%9C%A4%EC%84%A0"
#    },
#    {
#     "name": "Neil Diamond",
#     "url": "http://twitter.com/search?q=%22Neil+Diamond%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Neil+Diamond%22"
#    },
#    {
#     "name": "ACEDE",
#     "url": "http://twitter.com/search?q=ACEDE",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "ACEDE"
#    },
#    {
#     "name": "Swansea",
#     "url": "http://twitter.com/search?q=Swansea",
#     "promoted_content": null,
#     "tweet_volume": 124710,
#     "query": "Swansea"
#    },
#    {
#     "name": "Aran",
#     "url": "http://twitter.com/search?q=Aran",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "Aran"
#    },
#    {
#     "name": "Lloyd Pope",
#     "url": "http://twitter.com/search?q=%22Lloyd+Pope%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Lloyd+Pope%22"
#    },
#    {
#     "name": "Oriente Petrolero",
#     "url": "http://twitter.com/search?q=%22Oriente+Petrolero%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22Oriente+Petrolero%22"
#    },
#    {
#     "name": "John Green",
#     "url": "http://twitter.com/search?q=%22John+Green%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%22John+Green%22"
#    },
#    {
#     "name": "#DeseoOculto",
#     "url": "http://twitter.com/search?q=%23DeseoOculto",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23DeseoOculto"
#    },
#    {
#     "name": "#PorqueSoyMexicano",
#     "url": "http://twitter.com/search?q=%23PorqueSoyMexicano",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23PorqueSoyMexicano"
#    },
#    {
#     "name": "#isola",
#     "url": "http://twitter.com/search?q=%23isola",
#     "promoted_content": null,
#     "tweet_volume": 117218,
#     "query": "%23isola"
#    },
#    {
#     "name": "#\u0634\u0647\u0627\u062f\u062a\u0646\u0627_\u0628\u0643\u0627\u0644\u0648\u0631\u064a\u0648\u0633_\u0648\u0639\u0627\u0637\u0644\u064a\u0646",
#     "url": "http://twitter.com/search?q=%23%D8%B4%D9%87%D8%A7%D8%AF%D8%AA%D9%86%D8%A7_%D8%A8%D9%83%D8%A7%D9%84%D9%88%D8%B1%D9%8A%D9%88%D8%B3_%D9%88%D8%B9%D8%A7%D8%B7%D9%84%D9%8A%D9%86",
#     "promoted_content": null,
#     "tweet_volume": 25149,
#     "query": "%23%D8%B4%D9%87%D8%A7%D8%AF%D8%AA%D9%86%D8%A7_%D8%A8%D9%83%D8%A7%D9%84%D9%88%D8%B1%D9%8A%D9%88%D8%B3_%D9%88%D8%B9%D8%A7%D8%B7%D9%84%D9%8A%D9%86"
#    },
#    {
#     "name": "#PumpRules",
#     "url": "http://twitter.com/search?q=%23PumpRules",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23PumpRules"
#    },
#    {
#     "name": "#OOutroLadoParaiso",
#     "url": "http://twitter.com/search?q=%23OOutroLadoParaiso",
#     "promoted_content": null,
#     "tweet_volume": 15380,
#     "query": "%23OOutroLadoParaiso"
#    },
#    {
#     "name": "#TercaDetremuraSDV",
#     "url": "http://twitter.com/search?q=%23TercaDetremuraSDV",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TercaDetremuraSDV"
#    },
#    {
#     "name": "#AdiosHaiti",
#     "url": "http://twitter.com/search?q=%23AdiosHaiti",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23AdiosHaiti"
#    },
#    {
#     "name": "#LunesIntratable",
#     "url": "http://twitter.com/search?q=%23LunesIntratable",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23LunesIntratable"
#    },
#    {
#     "name": "#aLibertina",
#     "url": "http://twitter.com/search?q=%23aLibertina",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23aLibertina"
#    },
#    {
#     "name": "#EnElGymNuncaFalta",
#     "url": "http://twitter.com/search?q=%23EnElGymNuncaFalta",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23EnElGymNuncaFalta"
#    },
#    {
#     "name": "#ChileLindo",
#     "url": "http://twitter.com/search?q=%23ChileLindo",
#     "promoted_content": null,
#     "tweet_volume": 31729,
#     "query": "%23ChileLindo"
#    },
#    {
#     "name": "#\u0628\u0646_\u0634\u0631\u0642\u064a_\u0647\u0644\u0627\u0644\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A8%D9%86_%D8%B4%D8%B1%D9%82%D9%8A_%D9%87%D9%84%D8%A7%D9%84%D9%8A",
#     "promoted_content": null,
#     "tweet_volume": 101493,
#     "query": "%23%D8%A8%D9%86_%D8%B4%D8%B1%D9%82%D9%8A_%D9%87%D9%84%D8%A7%D9%84%D9%8A"
#    },
#    {
#     "name": "#UnlikelyHomeworkExcuses",
#     "url": "http://twitter.com/search?q=%23UnlikelyHomeworkExcuses",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23UnlikelyHomeworkExcuses"
#    },
#    {
#     "name": "#TheAlienist",
#     "url": "http://twitter.com/search?q=%23TheAlienist",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23TheAlienist"
#    },
#    {
#     "name": "#CorderoAlPaloMV",
#     "url": "http://twitter.com/search?q=%23CorderoAlPaloMV",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23CorderoAlPaloMV"
#    },
#    {
#     "name": "#COAC2018P14",
#     "url": "http://twitter.com/search?q=%23COAC2018P14",
#     "promoted_content": null,
#     "tweet_volume": 12313,
#     "query": "%23COAC2018P14"
#    },
#    {
#     "name": "#UEVenezuelaSeRespeta",
#     "url": "http://twitter.com/search?q=%23UEVenezuelaSeRespeta",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23UEVenezuelaSeRespeta"
#    },
#    {
#     "name": "#ReasonsToStayInside",
#     "url": "http://twitter.com/search?q=%23ReasonsToStayInside",
#     "promoted_content": null,
#     "tweet_volume": 10121,
#     "query": "%23ReasonsToStayInside"
#    },
#    {
#     "name": "#FFCsegueFFC",
#     "url": "http://twitter.com/search?q=%23FFCsegueFFC",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23FFCsegueFFC"
#    },
#    {
#     "name": "#CondenaTRF4",
#     "url": "http://twitter.com/search?q=%23CondenaTRF4",
#     "promoted_content": null,
#     "tweet_volume": 86015,
#     "query": "%23CondenaTRF4"
#    },
#    {
#     "name": "#DiosdadoNarcoLLORON",
#     "url": "http://twitter.com/search?q=%23DiosdadoNarcoLLORON",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "query": "%23DiosdadoNarcoLLORON"
#    }
#   ],
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# {
#  "lang": "ja",
#  "retweet_count": 0,
#  "in_reply_to_status_id_str": null,
#  "text": "iPhone\u30fb\u30b9\u30de\u30db\u30fb\u30b2\u30fc\u30e0\u30fb\u30d6\u30eb\u30fc\u30ec\u30a4\u8cb7\u3044\u53d6\u308a\u307e\u3059\uff01\n\u58ca\u308c\u305f iPhone \u3067\u3082\u5927\u6b53\u8fce\uff01\u305f\u3060\u3044\u307e \u8cb7\u53d6 \u30ad\u30e3\u30f3\u30da\u30fc\u30f3\u4e2d\u306b\u3064\u304d\u3001\u8907\u6570\u304a\u6301\u3061\u3044\u305f\u3060\u304f\u3068 \u91d1\u984d\uff35\uff30\uff01\n\u8cb7\u53d6 \u30d6\u30ed\u30b0\u3082\u3084\u3063\u3066\u307e\u3059\uff01\u8a73\u3057\u304f\u306f\u3053\u3061\u3089 \u2192 https://t.co/0iOzwzAqC2",
#  "retweeted": false,
#  "geo": null,
#  "favorited": false,
#  "place": null,
#  "id": 955638758119948288,
#  "source": "<a href=\"http://twirobo.com/\" rel=\"nofollow\">twiroboJP</a>",
#  "truncated": false,
#  "created_at": "Tue Jan 23 03:10:09 +0000 2018",
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "hashtags": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/0iOzwzAqC2",
#     "expanded_url": "https://goo.gl/QP7ToH",
#     "display_url": "goo.gl/QP7ToH",
#     "indices": [
#      104,
#      127
#     ]
#    }
#   ]
#  },
#  "contributors": null,
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id_str": "955638758119948288",
#  "metadata": {
#   "result_type": "recent",
#   "iso_language_code": "ja"
#  },
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "coordinates": null,
#  "possibly_sensitive": false,
#  "user": {
#   "has_extended_profile": false,
#   "translator_type": "none",
#   "location": "\u6771\u4eac\u90fd\u516b\u738b\u5b50\u5e02\u9ad8\u5009\u753a36-1",
#   "profile_background_tile": false,
#   "protected": false,
#   "favourites_count": 12,
#   "is_translation_enabled": false,
#   "profile_use_background_image": true,
#   "utc_offset": null,
#   "default_profile": false,
#   "profile_link_color": "DD2E44",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/931438569008148480/8ZZXFF8C_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/181128904/1511011851",
#   "verified": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/931438569008148480/8ZZXFF8C_normal.jpg",
#   "notifications": false,
#   "id": 181128904,
#   "profile_text_color": "333333",
#   "created_at": "Sat Aug 21 10:42:37 +0000 2010",
#   "listed_count": 13,
#   "following": false,
#   "time_zone": null,
#   "entities": {
#    "description": {
#     "urls": []
#    },
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/1dmS7zR4fR",
#       "expanded_url": "http://goo.gl/8mgqkK",
#       "display_url": "goo.gl/8mgqkK",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    }
#   },
#   "profile_background_color": "C0DEED",
#   "url": "https://t.co/1dmS7zR4fR",
#   "follow_request_sent": false,
#   "id_str": "181128904",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/138269029/doramarogo.gif",
#   "geo_enabled": true,
#   "default_profile_image": false,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/138269029/doramarogo.gif",
#   "friends_count": 37,
#   "contributors_enabled": false,
#   "followers_count": 217,
#   "screen_name": "dorama_takakura",
#   "description": "iPhone\u8cb7\u53d6\uff06\u8ca9\u58f2\u3001\u30ec\u30f3\u30bf\u30ebDVD\uff65CD\u2022\u3001\u30b3\u30df\u30c3\u30af\u2022\u30b2\u30fc\u30e0\u2022DVD\u2022CD\u8cb7\u53d6\uff06\u8ca9\u58f2\u306e\u304a\u5e97\u3067\u3059\u266a \u25c6JR\u516b\u738b\u5b50\u99c5\u304b\u3089\u8eca\u3067\u7d0410\u5206/JR\u8c4a\u7530\u99c5\u304b\u3089\u5f92\u6b69\u3067\u7d0420\u5206\u25c6\u99d0\u8eca\u5834\u5b8c\u5099\u25c6TEL 042-631-4841 \u25c6\u55b6\u696d\u6642\u9593 10:00\uff5e\u7fcc1:00",
#   "lang": "ja",
#   "name": "\u30c9\u30e9\u30de\u9ad8\u5009\u5e97",
#   "statuses_count": 2307,
#   "profile_sidebar_border_color": "C0DEED",
#   "is_translator": false
#  }
# }
# {
#  "lang": "zh",
#  "retweet_count": 0,
#  "in_reply_to_status_id_str": null,
#  "text": "\u6211\u9876\u4e86\u4e00\u4e2a @YouTube \u89c6\u9891 https://t.co/7P3F8U743X iPhone Ringtone (Violin Remix)",
#  "retweeted": false,
#  "geo": null,
#  "favorited": false,
#  "place": null,
#  "id": 955638800645943296,
#  "source": "<a href=\"http://www.google.com/\" rel=\"nofollow\">Google</a>",
#  "truncated": false,
#  "created_at": "Tue Jan 23 03:10:19 +0000 2018",
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "hashtags": [],
#   "user_mentions": [
#    {
#     "name": "YouTube",
#     "id_str": "10228272",
#     "indices": [
#      6,
#      14
#     ],
#     "id": 10228272,
#     "screen_name": "YouTube"
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/7P3F8U743X",
#     "expanded_url": "http://youtu.be/MQqbXDy85fc?a",
#     "display_url": "youtu.be/MQqbXDy85fc?a",
#     "indices": [
#      18,
#      41
#     ]
#    }
#   ]
#  },
#  "contributors": null,
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id_str": "955638800645943296",
#  "metadata": {
#   "result_type": "recent",
#   "iso_language_code": "zh"
#  },
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "coordinates": null,
#  "possibly_sensitive": false,
#  "user": {
#   "has_extended_profile": false,
#   "translator_type": "none",
#   "location": "NY MSM",
#   "profile_background_tile": false,
#   "protected": false,
#   "favourites_count": 9,
#   "is_translation_enabled": false,
#   "profile_use_background_image": true,
#   "utc_offset": null,
#   "default_profile": true,
#   "profile_link_color": "1DA1F2",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/532612086636236800/iS6Ftwh6_normal.jpeg",
#   "verified": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/532612086636236800/iS6Ftwh6_normal.jpeg",
#   "notifications": false,
#   "id": 2873842289,
#   "profile_text_color": "333333",
#   "created_at": "Wed Nov 12 15:20:27 +0000 2014",
#   "listed_count": 0,
#   "following": false,
#   "time_zone": null,
#   "entities": {
#    "description": {
#     "urls": []
#    },
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/0l5DtlRF8J",
#       "expanded_url": "http://weibo.com/norghmbichiesz",
#       "display_url": "weibo.com/norghmbichiesz",
#       "indices": [
#        0,
#        22
#       ]
#      }
#     ]
#    }
#   },
#   "profile_background_color": "C0DEED",
#   "url": "http://t.co/0l5DtlRF8J",
#   "follow_request_sent": false,
#   "id_str": "2873842289",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "geo_enabled": false,
#   "default_profile_image": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "friends_count": 17,
#   "contributors_enabled": false,
#   "followers_count": 16,
#   "screen_name": "norghmbichiesz",
#   "description": "",
#   "lang": "zh-CN",
#   "name": "Shuwen Zhang",
#   "statuses_count": 885,
#   "profile_sidebar_border_color": "C0DEED",
#   "is_translator": false
#  }
# }

# %%
# Storing Json file
def json_file(filename, data = None, delay = 0.1):
    try:
        if data == None:
            with open('{0}.json'.format(filename), "r", encoding = "utf-8") as f:
                return json.load(f)
        else:
            with open('{0}.json'.format(filename), 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False)
    except:
        print('Check file')

    
q = 'bitcoin'

twitter_api = oauth_login()
results = twitter_search(twitter_api, q, max_results=10)

json_file(q, data=results)
test_res = json_file(q)

RenderJSON(test_res[0])
# Out:
# <div id="c48c7514-7560-4599-bc3d-a0b05122fbf0" style="height: 100px; width:100%;"></div>

# %%
# Finding topics of interest by using the filtering capablities it offers.

# Query terms

q = 'bitcoin' # Comma-separated list of terms

print ('Filtering the public timeline for track="%s"' % (q,))

# Returns an instance of twitter.Twitter
twitter_api = oauth_login()

# Reference the self.auth parameter
twitter_stream = twitter.TwitterStream(auth=twitter_api.auth)

stream = twitter_stream.statuses.filter(track=q)

count = 0
for tweet in stream:
    while count<10:
        print (tweet['text'])
        count += 1
    break
# Out:
# Filtering the public timeline for track="bitcoin"
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…
# RT @caviar0x: “Our solution diversifies outside the asset class by combining #crypto investments with the #RealEstate debt market,” said Ca…

# %%
# Extract tweet entities
def extract_tweet_entities(statuses):

    if len(statuses) == 0:
        return [], [], [], [], []
    
    screen_names = [ user_mention['screen_name'] 
                         for status in statuses
                            for user_mention in status['entities']['user_mentions'] ]
    
    hashtags = [ hashtag['text'] 
                     for status in statuses 
                        for hashtag in status['entities']['hashtags'] ]

    urls = [ url['expanded_url'] 
                     for status in statuses 
                        for url in status['entities']['urls'] ]
    
    symbols = [ symbol['text']
                   for status in statuses
                       for symbol in status['entities']['symbols'] ]
               
    # In some circumstances (such as search results), the media entity
    # may not appear
    try:
        media = [ media['url'] 
                         for status in statuses  
                            for media in status['entities']['media'] ]
    except:
        media = []

    return screen_names, hashtags, urls, media, symbols

# Sample usage

q = 'Bitcoin'

statuses = twitter_search(twitter_api, q)

screen_names, hashtags, urls, media, symbols = extract_tweet_entities(statuses)
    
# Explore the first five items for each...

print (json.dumps(screen_names[0:5], indent=1))
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(urls[0:5], indent=1))
print (json.dumps(media[0:5], indent=1))
print (json.dumps(symbols[0:5], indent=1))
# Out:
# [
#  "Thetubbygoat",
#  "dogmouthbear",
#  "ErikVoorhees",
#  "dougvk",
#  "ReutersTech"
# ]
# [
#  "Cindicator",
#  "bitcoin",
#  "Security",
#  "Bitcoin",
#  "satoshi"
# ]
# [
#  "https://medium.com/p/how-to-cost-effectively-buy-cnd-cindicator-with-usd-d771b4918c42",
#  "https://medium.com/@dougvk/run-your-own-mainnet-lightning-node-2d2eab628a8b",
#  "http://feeds.reuters.com/~r/reuters/technologyNews/~3/ljFoE4qHrhE/south-korea-to-ban-cryptocurrency-traders-from-using-anonymous-bank-accounts-idUSKBN1FC069",
#  "http://dlvr.it/QCLPDy",
#  "https://forum.bitcoin.com/"
# ]
# []
# [
#  "CND",
#  "BSTY",
#  "BTC",
#  "BTC",
#  "LCD"
# ]

# %%
# Find the most popular tweets in a collection of tweets
def find_popular_tweets(twitter_api, statuses, retweet_threshold=100):
        
    return [ status
                for status in statuses 
                    if status['retweet_count'] > retweet_threshold ] 
    
# Sample usage

q = "bitcoin"

twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q, max_results=200)

popular_tweets = find_popular_tweets(twitter_api, search_results)

for tweet in popular_tweets:
    print (tweet['text'], tweet['retweet_count'])
# Out:
# RT @LucydLtd: Great day at The North American Bitcoin Conference. Excellent presentation by our CEO and very warm reception of Lucyd by att… 109
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @ErikVoorhees: “Run your own mainnet Lightning Node” by @dougvk https://t.co/ojq13cnlz8 #bitcoin 152
# RT @JonErlichman: Things that didn't exist when the Eagles &amp; Patriots played in the 2005 Super Bowl:
#
# iPhone
# Instagram
# YouTube
# Snapchat
# Twi… 1858
# RT @SudanGoldCoin: ABC News is now with us!! To find our more - visit: https://t.co/BTNO2OJpLz
# #SudanGC #Sudan #Gold #Coin #Money #blockch… 887
# RT @Crypticsup: #cryptics #crowdsale #bitcoin  #ico How to start cryptocurrency trading
# https://t.co/ETH2QCREde https://t.co/9WMz8jPhYU 105
# RT @nytimes: Creating a new Bitcoin requires electricity. A lot of it. https://t.co/PKlvAEn9WA 159
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @WadeCano: #GIVEAWAY! I’m giving away 1 #Ethereum to one lucky follower who retweets this post and follows my account. Follow and retwee… 299
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @LucydLtd: Greetings from the Lucyd team! #TNABC #Bitcoin $BTC $LCD #Btc #Ethereum #ETH $ETH #ICO #blockchain #blockchaintechnology #tec… 118
# RT @COTInetwork: From high school dropout to #Bitcoin millionaire, Erik Finman discusses his strategy for buying #cryptocurrencies. Click t… 366
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467
# RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา… 9467

# %%
# Finding the most popular tweet entities in a collection of tweets
def get_common_tweet_entities(statuses, entity_threshold=3):

    # Create a flat list of all tweet entities
    tweet_entities = [  e
                        for status in statuses
                            for entity_type in extract_tweet_entities([status]) 
                                for e in entity_type 
                     ]

    c = Counter(tweet_entities).most_common()

    # Compute frequencies
    return [ (k,v) 
             for (k,v) in c
                 if v >= entity_threshold
           ]



q = 'bitcoin'

twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q, max_results=100)
common_entities = get_common_tweet_entities(search_results)

print ("Most common tweet entities")
print (common_entities)
# Out:
# Most common tweet entities
# [('bitcoin', 17), ('Bitcoin', 9), ('dogmouthbear', 9), ('cryptocurrency', 6), ('btc', 5), ('BTC', 4), ('Ethereum', 3), ('Crypto', 3), ('cryptocurrencies', 3), ('crypto', 3)]

# %%
from prettytable import PrettyTable

# Get some frequency data

twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q, max_results=100)
common_entities = get_common_tweet_entities(search_results)

# Use PrettyTable to create a nice tabular display

pt = PrettyTable(field_names=['Entity', 'Count']) 
[ pt.add_row(kv) for kv in common_entities ]
pt.align['Entity'], pt.align['Count'] = 'l', 'r' # Set column alignment
print (pt)
# Out:
# +------------------+-------+
# | Entity           | Count |
# +------------------+-------+
# | bitcoin          |    15 |
# | dogmouthbear     |    10 |
# | Bitcoin          |     8 |
# | cryptocurrency   |     6 |
# | btc              |     4 |
# | cryptocurrencies |     3 |
# | crypto           |     3 |
# | BTC              |     3 |
# +------------------+-------+

# %%
# Finding users who have retweeted a status

twitter_api = oauth_login()

print ("""User IDs for retweeters of a tweet by @fperez_org
that was retweeted by @SocialWebMining and that @jyeee then retweeted
from @SocialWebMining's timeline\n""")
print (twitter_api.statuses.retweeters.ids(_id=334188056905129984)['ids'])
print (json.dumps(twitter_api.statuses.show(_id=334188056905129984), indent=1))

print ("@SocialWeb's retweet of @fperez_org's tweet\n")
print (twitter_api.statuses.retweeters.ids(_id=345723917798866944)['ids'])
print (json.dumps(twitter_api.statuses.show(_id=345723917798866944), indent=1))

print ("@jyeee's retweet of @fperez_org's tweet\n")
print (twitter_api.statuses.retweeters.ids(_id=338835939172417537)['ids'])
print (json.dumps(twitter_api.statuses.show(_id=338835939172417537), indent=1))
# Out:
# User IDs for retweeters of a tweet by @fperez_org
# that was retweeted by @SocialWebMining and that @jyeee then retweeted
# from @SocialWebMining's timeline
#
# [17930287, 132373965, 13085242, 66592853, 25696968]
# {
#  "retweet_count": 5,
#  "geo": null,
#  "text": "Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://t.co/56giCSjcqw",
#  "retweeted": false,
#  "in_reply_to_status_id_str": null,
#  "id_str": "334188056905129984",
#  "favorited": false,
#  "place": null,
#  "coordinates": null,
#  "id": 334188056905129984,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "truncated": false,
#  "contributors": null,
#  "favorite_count": 9,
#  "entities": {
#   "symbols": [],
#   "hashtags": [],
#   "user_mentions": [
#    {
#     "name": "MiningTheSocialWeb",
#     "id_str": "132373965",
#     "indices": [
#      82,
#      98
#     ],
#     "id": 132373965,
#     "screen_name": "SocialWebMining"
#    },
#    {
#     "name": "Matthew Russell",
#     "id_str": "13085242",
#     "indices": [
#      102,
#      115
#     ],
#     "id": 13085242,
#     "screen_name": "ptwobrussell"
#    }
#   ],
#   "urls": [
#    {
#     "url": "http://t.co/56giCSjcqw",
#     "expanded_url": "http://on.fb.me/11WCD9E",
#     "display_url": "on.fb.me/11WCD9E",
#     "indices": [
#      116,
#      138
#     ]
#    }
#   ]
#  },
#  "is_quote_status": false,
#  "created_at": "Tue May 14 06:06:56 +0000 2013",
#  "in_reply_to_user_id": null,
#  "possibly_sensitive_appealable": false,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "lang": "en",
#  "possibly_sensitive": false,
#  "user": {
#   "has_extended_profile": false,
#   "translator_type": "none",
#   "location": "Berkeley, CA",
#   "profile_background_tile": false,
#   "protected": false,
#   "favourites_count": 6538,
#   "is_translation_enabled": false,
#   "profile_use_background_image": true,
#   "utc_offset": -28800,
#   "default_profile": true,
#   "profile_link_color": "1DA1F2",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/244991150/1404790002",
#   "verified": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#   "notifications": false,
#   "id": 244991150,
#   "profile_text_color": "333333",
#   "created_at": "Sun Jan 30 16:28:09 +0000 2011",
#   "listed_count": 726,
#   "following": false,
#   "time_zone": "Pacific Time (US & Canada)",
#   "entities": {
#    "description": {
#     "urls": []
#    },
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/J7UDLpykqU",
#       "expanded_url": "http://fperez.org",
#       "display_url": "fperez.org",
#       "indices": [
#        0,
#        22
#       ]
#      }
#     ]
#    }
#   },
#   "profile_background_color": "C0DEED",
#   "url": "http://t.co/J7UDLpykqU",
#   "follow_request_sent": false,
#   "id_str": "244991150",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "geo_enabled": true,
#   "default_profile_image": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "friends_count": 517,
#   "contributors_enabled": false,
#   "followers_count": 15348,
#   "screen_name": "fperez_org",
#   "description": "Physicist, data scientist, @IPythonDev creator (evolved into @ProjectJupyter). Asst. Professor in Statistics UC Berkeley, climber, advisor to @plotlygraphs.",
#   "lang": "en",
#   "name": "Fernando Perez",
#   "statuses_count": 7015,
#   "profile_sidebar_border_color": "C0DEED",
#   "is_translator": false
#  },
#  "in_reply_to_status_id": null
# }
# @SocialWeb's retweet of @fperez_org's tweet
#
# []
# {
#  "retweet_count": 5,
#  "geo": null,
#  "text": "RT @fperez_org: Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://\u2026",
#  "retweeted": false,
#  "in_reply_to_status_id_str": null,
#  "id_str": "345723917798866944",
#  "favorited": false,
#  "place": null,
#  "coordinates": null,
#  "id": 345723917798866944,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "truncated": false,
#  "contributors": null,
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "hashtags": [],
#   "user_mentions": [
#    {
#     "name": "Fernando Perez",
#     "id_str": "244991150",
#     "indices": [
#      3,
#      14
#     ],
#     "id": 244991150,
#     "screen_name": "fperez_org"
#    },
#    {
#     "name": "MiningTheSocialWeb",
#     "id_str": "132373965",
#     "indices": [
#      98,
#      114
#     ],
#     "id": 132373965,
#     "screen_name": "SocialWebMining"
#    },
#    {
#     "name": "Matthew Russell",
#     "id_str": "13085242",
#     "indices": [
#      118,
#      131
#     ],
#     "id": 13085242,
#     "screen_name": "ptwobrussell"
#    }
#   ],
#   "urls": []
#  },
#  "is_quote_status": false,
#  "created_at": "Sat Jun 15 02:06:19 +0000 2013",
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "retweeted_status": {
#   "lang": "en",
#   "retweet_count": 5,
#   "in_reply_to_status_id_str": null,
#   "text": "Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://t.co/56giCSjcqw",
#   "retweeted": false,
#   "geo": null,
#   "favorited": false,
#   "place": null,
#   "id": 334188056905129984,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "truncated": false,
#   "created_at": "Tue May 14 06:06:56 +0000 2013",
#   "favorite_count": 9,
#   "entities": {
#    "symbols": [],
#    "hashtags": [],
#    "user_mentions": [
#     {
#      "name": "MiningTheSocialWeb",
#      "id_str": "132373965",
#      "indices": [
#       82,
#       98
#      ],
#      "id": 132373965,
#      "screen_name": "SocialWebMining"
#     },
#     {
#      "name": "Matthew Russell",
#      "id_str": "13085242",
#      "indices": [
#       102,
#       115
#      ],
#      "id": 13085242,
#      "screen_name": "ptwobrussell"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/56giCSjcqw",
#      "expanded_url": "http://on.fb.me/11WCD9E",
#      "display_url": "on.fb.me/11WCD9E",
#      "indices": [
#       116,
#       138
#      ]
#     }
#    ]
#   },
#   "contributors": null,
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id_str": "334188056905129984",
#   "in_reply_to_user_id": null,
#   "possibly_sensitive_appealable": false,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "coordinates": null,
#   "possibly_sensitive": false,
#   "user": {
#    "has_extended_profile": false,
#    "translator_type": "none",
#    "location": "Berkeley, CA",
#    "profile_background_tile": false,
#    "protected": false,
#    "favourites_count": 6538,
#    "is_translation_enabled": false,
#    "profile_use_background_image": true,
#    "utc_offset": -28800,
#    "default_profile": true,
#    "profile_link_color": "1DA1F2",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/244991150/1404790002",
#    "verified": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "notifications": false,
#    "id": 244991150,
#    "profile_text_color": "333333",
#    "created_at": "Sun Jan 30 16:28:09 +0000 2011",
#    "listed_count": 726,
#    "following": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "entities": {
#     "description": {
#      "urls": []
#     },
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/J7UDLpykqU",
#        "expanded_url": "http://fperez.org",
#        "display_url": "fperez.org",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     }
#    },
#    "profile_background_color": "C0DEED",
#    "url": "http://t.co/J7UDLpykqU",
#    "follow_request_sent": false,
#    "id_str": "244991150",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "geo_enabled": true,
#    "default_profile_image": false,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "friends_count": 517,
#    "contributors_enabled": false,
#    "followers_count": 15348,
#    "screen_name": "fperez_org",
#    "description": "Physicist, data scientist, @IPythonDev creator (evolved into @ProjectJupyter). Asst. Professor in Statistics UC Berkeley, climber, advisor to @plotlygraphs.",
#    "lang": "en",
#    "name": "Fernando Perez",
#    "statuses_count": 7015,
#    "profile_sidebar_border_color": "C0DEED",
#    "is_translator": false
#   }
#  },
#  "lang": "en",
#  "user": {
#   "has_extended_profile": false,
#   "translator_type": "regular",
#   "location": "Franklin, TN",
#   "profile_background_tile": false,
#   "protected": false,
#   "favourites_count": 901,
#   "is_translation_enabled": false,
#   "profile_use_background_image": true,
#   "utc_offset": -21600,
#   "default_profile": false,
#   "profile_link_color": "EE8336",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000365424290/cbdedf17eb021ce95ddce059a90c1787_normal.jpeg",
#   "verified": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000365424290/cbdedf17eb021ce95ddce059a90c1787_normal.jpeg",
#   "notifications": false,
#   "id": 13085242,
#   "profile_text_color": "333333",
#   "created_at": "Tue Feb 05 08:16:12 +0000 2008",
#   "listed_count": 184,
#   "following": false,
#   "time_zone": "Central Time (US & Canada)",
#   "entities": {
#    "description": {
#     "urls": []
#    },
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/AzFoM9TBPO",
#       "expanded_url": "http://MiningTheSocialWeb.com",
#       "display_url": "MiningTheSocialWeb.com",
#       "indices": [
#        0,
#        22
#       ]
#      }
#     ]
#    }
#   },
#   "profile_background_color": "888888",
#   "url": "http://t.co/AzFoM9TBPO",
#   "follow_request_sent": false,
#   "id_str": "13085242",
#   "profile_sidebar_fill_color": "F7F7F7",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/112353046/twitter-1.4.2.gif",
#   "geo_enabled": false,
#   "default_profile_image": false,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/112353046/twitter-1.4.2.gif",
#   "friends_count": 162,
#   "contributors_enabled": false,
#   "followers_count": 2029,
#   "screen_name": "ptwobrussell",
#   "description": "Computer Scientist. Technologist. CrossFitter. Triathlete. Author.",
#   "lang": "en",
#   "name": "Matthew Russell",
#   "statuses_count": 1507,
#   "profile_sidebar_border_color": "888888",
#   "is_translator": false
#  },
#  "in_reply_to_status_id": null
# }
# @jyeee's retweet of @fperez_org's tweet
# []
# {
#  "retweet_count": 5,
#  "geo": null,
#  "text": "RT @fperez_org: Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://\u2026",
#  "retweeted": false,
#  "in_reply_to_status_id_str": null,
#  "id_str": "338835939172417537",
#  "favorited": false,
#  "place": null,
#  "coordinates": null,
#  "id": 338835939172417537,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "truncated": false,
#  "contributors": null,
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "hashtags": [],
#   "user_mentions": [
#    {
#     "name": "Fernando Perez",
#     "id_str": "244991150",
#     "indices": [
#      3,
#      14
#     ],
#     "id": 244991150,
#     "screen_name": "fperez_org"
#    },
#    {
#     "name": "MiningTheSocialWeb",
#     "id_str": "132373965",
#     "indices": [
#      98,
#      114
#     ],
#     "id": 132373965,
#     "screen_name": "SocialWebMining"
#    },
#    {
#     "name": "Matthew Russell",
#     "id_str": "13085242",
#     "indices": [
#      118,
#      131
#     ],
#     "id": 13085242,
#     "screen_name": "ptwobrussell"
#    }
#   ],
#   "urls": []
#  },
#  "is_quote_status": false,
#  "created_at": "Mon May 27 01:55:57 +0000 2013",
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "retweeted_status": {
#   "lang": "en",
#   "retweet_count": 5,
#   "in_reply_to_status_id_str": null,
#   "text": "Thrilled to see more books w/ computational content as IPython notebooks: 2nd Ed. @SocialWebMining by @ptwobrussell http://t.co/56giCSjcqw",
#   "retweeted": false,
#   "geo": null,
#   "favorited": false,
#   "place": null,
#   "id": 334188056905129984,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "truncated": false,
#   "created_at": "Tue May 14 06:06:56 +0000 2013",
#   "favorite_count": 9,
#   "entities": {
#    "symbols": [],
#    "hashtags": [],
#    "user_mentions": [
#     {
#      "name": "MiningTheSocialWeb",
#      "id_str": "132373965",
#      "indices": [
#       82,
#       98
#      ],
#      "id": 132373965,
#      "screen_name": "SocialWebMining"
#     },
#     {
#      "name": "Matthew Russell",
#      "id_str": "13085242",
#      "indices": [
#       102,
#       115
#      ],
#      "id": 13085242,
#      "screen_name": "ptwobrussell"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/56giCSjcqw",
#      "expanded_url": "http://on.fb.me/11WCD9E",
#      "display_url": "on.fb.me/11WCD9E",
#      "indices": [
#       116,
#       138
#      ]
#     }
#    ]
#   },
#   "contributors": null,
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id_str": "334188056905129984",
#   "in_reply_to_user_id": null,
#   "possibly_sensitive_appealable": false,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "coordinates": null,
#   "possibly_sensitive": false,
#   "user": {
#    "has_extended_profile": false,
#    "translator_type": "none",
#    "location": "Berkeley, CA",
#    "profile_background_tile": false,
#    "protected": false,
#    "favourites_count": 6538,
#    "is_translation_enabled": false,
#    "profile_use_background_image": true,
#    "utc_offset": -28800,
#    "default_profile": true,
#    "profile_link_color": "1DA1F2",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/244991150/1404790002",
#    "verified": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1864199033/fperez_photo2_sm_normal.jpg",
#    "notifications": false,
#    "id": 244991150,
#    "profile_text_color": "333333",
#    "created_at": "Sun Jan 30 16:28:09 +0000 2011",
#    "listed_count": 726,
#    "following": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "entities": {
#     "description": {
#      "urls": []
#     },
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/J7UDLpykqU",
#        "expanded_url": "http://fperez.org",
#        "display_url": "fperez.org",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     }
#    },
#    "profile_background_color": "C0DEED",
#    "url": "http://t.co/J7UDLpykqU",
#    "follow_request_sent": false,
#    "id_str": "244991150",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "geo_enabled": true,
#    "default_profile_image": false,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "friends_count": 517,
#    "contributors_enabled": false,
#    "followers_count": 15348,
#    "screen_name": "fperez_org",
#    "description": "Physicist, data scientist, @IPythonDev creator (evolved into @ProjectJupyter). Asst. Professor in Statistics UC Berkeley, climber, advisor to @plotlygraphs.",
#    "lang": "en",
#    "name": "Fernando Perez",
#    "statuses_count": 7015,
#    "profile_sidebar_border_color": "C0DEED",
#    "is_translator": false
#   }
#  },
#  "lang": "en",
#  "user": {
#   "has_extended_profile": false,
#   "translator_type": "none",
#   "location": "Washington, DC",
#   "profile_background_tile": true,
#   "protected": false,
#   "favourites_count": 808,
#   "is_translation_enabled": false,
#   "profile_use_background_image": true,
#   "utc_offset": -18000,
#   "default_profile": false,
#   "profile_link_color": "009999",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/904172995060617220/5R83Sh9u_normal.jpg",
#   "verified": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/904172995060617220/5R83Sh9u_normal.jpg",
#   "notifications": false,
#   "id": 17930287,
#   "profile_text_color": "333333",
#   "created_at": "Sat Dec 06 22:27:09 +0000 2008",
#   "listed_count": 30,
#   "following": false,
#   "time_zone": "Eastern Time (US & Canada)",
#   "entities": {
#    "description": {
#     "urls": []
#    },
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/6oebaBkYVa",
#       "expanded_url": "http://www.linkedin.com/in/jyeee",
#       "display_url": "linkedin.com/in/jyeee",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    }
#   },
#   "profile_background_color": "131516",
#   "url": "https://t.co/6oebaBkYVa",
#   "follow_request_sent": false,
#   "id_str": "17930287",
#   "profile_sidebar_fill_color": "EFEFEF",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#   "geo_enabled": false,
#   "default_profile_image": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#   "friends_count": 391,
#   "contributors_enabled": false,
#   "followers_count": 187,
#   "screen_name": "jyeee",
#   "description": "",
#   "lang": "en",
#   "name": "jyeee",
#   "statuses_count": 1148,
#   "profile_sidebar_border_color": "EEEEEE",
#   "is_translator": false
#  },
#  "in_reply_to_status_id": null
# }

# %%
# Extracting a retweet's attribution

import re

def get_rt_attributions(tweet):

    # Regex adapted from Stack Overflow (http://bit.ly/1821y0J)

    rt_patterns = re.compile(r"(RT|via)((?:\b\W*@\w+)+)", re.IGNORECASE)
    rt_attributions = []

    # Inspect the tweet to see if it was produced with /statuses/retweet/:id.
    # See https://dev.twitter.com/docs/api/1.1/get/statuses/retweets/%3Aid.
    
    if 'retweeted_status' in tweet:
        attribution = tweet['retweeted_status']['user']['screen_name'].lower()
        rt_attributions.append(attribution)

    try:
        rt_attributions += [ 
                        mention.strip() 
                        for mention in rt_patterns.findall(tweet['text'])[0][1].split() 
                      ]
    except IndexError as e:
        pass

    # Filter out any duplicates

    return list(set([rta.strip("@").lower() for rta in rt_attributions]))

# Sample usage
twitter_api = oauth_login()

tweet = twitter_api.statuses.show(_id=214746575765913602)
print (get_rt_attributions(tweet))

tweet = twitter_api.statuses.show(_id=345723917798866944)
print (get_rt_attributions(tweet))
# Out:
# ['jyeee']
# ['fperez_org']

# %%
# Making robust Twitter requests
def make_twitter_request(twitter_api_func, max_errors=10, *args, **kw): 
    
    # A nested helper function that handles common HTTPErrors. Return an updated
    # value for wait_period if the problem is a 500 level error. Block until the
    # rate limit is reset if it's a rate limiting issue (429 error). Returns None
    # for 401 and 404 errors, which requires special handling by the caller.
    def handle_twitter_http_error(e, wait_period=2, sleep_when_rate_limited=True):
    
        if wait_period > 3600: # Seconds
            print ('Too many retries. Quitting.')
            raise e
        
        if e.e.code == 401:
            print ('Encountered 401 Error (Not Authorized)')
            return None
        elif e.e.code == 404:
            print ('Encountered 404 Error (Not Found)')
            return None
        elif e.e.code == 429: 
            print ('Encountered 429 Error (Rate Limit Exceeded)')
            if sleep_when_rate_limited:
                print ("Retrying in 15 minutes...ZzZ...")
                sys.stderr.flush()
                time.sleep(60*15 + 5)
                print ('...ZzZ...Awake now and trying again.')
                return 2
            else:
                raise e # Caller must handle the rate limiting issue
        elif e.e.code in (500, 502, 503, 504):
            print ('Encountered %i Error. Retrying in %i seconds' % \
                (e.e.code, wait_period))
            time.sleep(wait_period)
            wait_period *= 1.5
            return wait_period
        else:
            raise e

    # End of nested helper function
    
    wait_period = 2 
    error_count = 0 

    while True:
        try:
            return twitter_api_func(*args, **kw)
        except twitter.api.TwitterHTTPError as e:
            error_count = 0 
            wait_period = handle_twitter_http_error(e, wait_period)
            if wait_period is None:
                return
        except URLError as e:
            error_count += 1
            time.sleep(wait_period)
            wait_period *= 1.5
            print("URLError encountered. Continuing.")
            if error_count > max_errors:
                print("Too many consecutive errors...bailing out.")
                raise
        except BadStatusLine as e:
            error_count += 1
            time.sleep(wait_period)
            wait_period *= 1.5
            print("BadStatusLine encountered. Continuing.")
            if error_count > max_errors:
                print ("Too many consecutive errors...bailing out.")
                raise


twitter_api = oauth_login()

response = make_twitter_request(twitter_api.users.lookup, 
                                screen_name="deanabb")

print (json.dumps(response, indent=1))
# Out:
# [
#  {
#   "has_extended_profile": false,
#   "translator_type": "none",
#   "location": "San Diego",
#   "profile_background_tile": true,
#   "protected": false,
#   "favourites_count": 522,
#   "is_translation_enabled": false,
#   "profile_use_background_image": true,
#   "utc_offset": -28800,
#   "default_profile": false,
#   "profile_link_color": "0084B4",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/573000010591166464/-GEuAmBe_normal.jpeg",
#   "status": {
#    "lang": "en",
#    "retweet_count": 2,
#    "in_reply_to_status_id_str": null,
#    "text": "Businesses Need Realistic Digital Marketing Expectations https://t.co/Px81TYsjyD",
#    "retweeted": false,
#    "geo": null,
#    "favorited": false,
#    "place": null,
#    "id": 954790010695266304,
#    "source": "<a href=\"http://www.linkedin.com/\" rel=\"nofollow\">LinkedIn</a>",
#    "truncated": false,
#    "created_at": "Sat Jan 20 18:57:32 +0000 2018",
#    "favorite_count": 0,
#    "entities": {
#     "symbols": [],
#     "hashtags": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/Px81TYsjyD",
#       "expanded_url": "https://lnkd.in/grDayug",
#       "display_url": "lnkd.in/grDayug",
#       "indices": [
#        57,
#        80
#       ]
#      }
#     ]
#    },
#    "contributors": null,
#    "is_quote_status": false,
#    "id_str": "954790010695266304",
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "coordinates": null,
#    "possibly_sensitive": false,
#    "in_reply_to_status_id": null
#   },
#   "profile_image_url": "http://pbs.twimg.com/profile_images/573000010591166464/-GEuAmBe_normal.jpeg",
#   "notifications": false,
#   "id": 17911125,
#   "profile_text_color": "333333",
#   "created_at": "Fri Dec 05 23:23:19 +0000 2008",
#   "listed_count": 331,
#   "following": true,
#   "time_zone": "Pacific Time (US & Canada)",
#   "entities": {
#    "description": {
#     "urls": []
#    },
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/3QnbWajbpC",
#       "expanded_url": "http://abbottanalytics.blogspot.com",
#       "display_url": "abbottanalytics.blogspot.com",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    }
#   },
#   "profile_background_color": "C0DEED",
#   "url": "https://t.co/3QnbWajbpC",
#   "follow_request_sent": false,
#   "id_str": "17911125",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/699908199/4bee5518ffde1de92d92f5f655238eec.png",
#   "geo_enabled": true,
#   "default_profile_image": false,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/699908199/4bee5518ffde1de92d92f5f655238eec.png",
#   "friends_count": 249,
#   "contributors_enabled": false,
#   "followers_count": 4705,
#   "screen_name": "deanabb",
#   "description": "Co-founder + Chief Data Scientist / SmarterHQ, @smarterhq, Author of Applied Predictive Analytics (Wiley). Regular talks & workshops  at @pawcon and @Tdwi.",
#   "lang": "en",
#   "name": "Dean Abbott",
#   "statuses_count": 3160,
#   "profile_sidebar_border_color": "FFFFFF",
#   "is_translator": false,
#   "verified": false
#  }
# ]

# %%
# Resolving user profile information
def get_user_profile(twitter_api, screen_names=None, user_ids=None):
   
    # Must have either screen_name or user_id (logical xor)
    assert (screen_names != None) != (user_ids != None), \
    "Must have screen_names or user_ids, but not both"
    
    items_to_info = {}

    items = screen_names or user_ids
    
    while len(items) > 0:

        # Process 100 items at a time per the API specifications for /users/lookup.
        # See https://dev.twitter.com/docs/api/1.1/get/users/lookup for details.
        
        items_str = ','.join([str(item) for item in items[:100]])
        items = items[100:]

        if screen_names:
            response = make_twitter_request(twitter_api.users.lookup, 
                                            screen_name=items_str)
        else: # user_ids
            response = make_twitter_request(twitter_api.users.lookup, 
                                            user_id=items_str)
    
        for user_info in response:
            if screen_names:
                items_to_info[user_info['screen_name']] = user_info
            else: # user_ids
                items_to_info[user_info['id']] = user_info

    return items_to_info

# Sample usage

twitter_api = oauth_login()

print (get_user_profile(twitter_api, screen_names=["deanabb", "kncukier"]))
# Out:
# {'deanabb': {'has_extended_profile': False, 'translator_type': 'none', 'location': 'San Diego', 'profile_background_tile': True, 'protected': False, 'favourites_count': 522, 'is_translation_enabled': False, 'profile_use_background_image': True, 'utc_offset': -28800, 'default_profile': False, 'profile_link_color': '0084B4', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/573000010591166464/-GEuAmBe_normal.jpeg', 'status': {'lang': 'en', 'retweet_count': 2, 'in_reply_to_status_id_str': None, 'text': 'Businesses Need Realistic Digital Marketing Expectations https://t.co/Px81TYsjyD', 'retweeted': False, 'geo': None, 'favorited': False, 'place': None, 'id': 954790010695266304, 'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>', 'truncated': False, 'created_at': 'Sat Jan 20 18:57:32 +0000 2018', 'favorite_count': 0, 'entities': {'symbols': [], 'hashtags': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Px81TYsjyD', 'expanded_url': 'https://lnkd.in/grDayug', 'display_url': 'lnkd.in/grDayug', 'indices': [57, 80]}]}, 'contributors': None, 'is_quote_status': False, 'id_str': '954790010695266304', 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'coordinates': None, 'possibly_sensitive': False, 'in_reply_to_status_id': None}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/573000010591166464/-GEuAmBe_normal.jpeg', 'notifications': False, 'id': 17911125, 'profile_text_color': '333333', 'created_at': 'Fri Dec 05 23:23:19 +0000 2008', 'listed_count': 331, 'following': True, 'time_zone': 'Pacific Time (US & Canada)', 'entities': {'description': {'urls': []}, 'url': {'urls': [{'url': 'https://t.co/3QnbWajbpC', 'expanded_url': 'http://abbottanalytics.blogspot.com', 'display_url': 'abbottanalytics.blogspot.com', 'indices': [0, 23]}]}}, 'profile_background_color': 'C0DEED', 'url': 'https://t.co/3QnbWajbpC', 'follow_request_sent': False, 'id_str': '17911125', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/699908199/4bee5518ffde1de92d92f5f655238eec.png', 'geo_enabled': True, 'default_profile_image': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/699908199/4bee5518ffde1de92d92f5f655238eec.png', 'friends_count': 249, 'contributors_enabled': False, 'followers_count': 4705, 'screen_name': 'deanabb', 'description': 'Co-founder + Chief Data Scientist / SmarterHQ, @smarterhq, Author of Applied Predictive Analytics (Wiley). Regular talks & workshops  at @pawcon and @Tdwi.', 'lang': 'en', 'name': 'Dean Abbott', 'statuses_count': 3160, 'profile_sidebar_border_color': 'FFFFFF', 'is_translator': False, 'verified': False}, 'kncukier': {'has_extended_profile': False, 'translator_type': 'none', 'location': '', 'profile_background_tile': False, 'protected': False, 'favourites_count': 14872, 'is_translation_enabled': False, 'profile_use_background_image': True, 'utc_offset': 32400, 'default_profile': False, 'profile_link_color': 'ABB8C2', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314798672/kncukier_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/250103509/1451863394', 'status': {'lang': 'en', 'retweet_count': 173, 'in_reply_to_status_id_str': None, 'text': 'RT @AMLwhere: This is such a tremendous opportunity for local journalists. Applications for the new Abrams Nieman Fellowships supporting lo…', 'retweeted': False, 'geo': None, 'favorited': False, 'place': None, 'id': 954644634218713088, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'truncated': False, 'created_at': 'Sat Jan 20 09:19:51 +0000 2018', 'favorite_count': 0, 'entities': {'symbols': [], 'hashtags': [], 'user_mentions': [{'name': 'Ann Marie Lipinski', 'id_str': '320959649', 'indices': [3, 12], 'id': 320959649, 'screen_name': 'AMLwhere'}], 'urls': []}, 'contributors': None, 'is_quote_status': False,  ...

# %%
# Extracting tweet entities from arbitrary text
import twitter_text

txt = "Looking forward to giving a new workshop on March 6 at the 2018 @KNIME Summit in Berlin: 'The Power of Random - Course: Using Perturbation Experiments to Improve Model Accuracy and Interpretation' https://www.knime.com/about/events/the-power-of-random-course-using-perturbation-experiments-to-improve-model-accuracy … #KNIMESummit2018 #OpenSource"

ex = twitter_text.Extractor(txt)

print ("Screen Names:", ex.extract_mentioned_screen_names_with_indices())
print ("URLs:", ex.extract_urls_with_indices())
print ("Hashtags:", ex.extract_hashtags_with_indices())
# Out:
# Screen Names: [{'indices': [64, 70], 'screen_name': 'KNIME'}]
# URLs: [{'url': 'https://www.knime.com/about/events/the-power-of-random-course-using-perturbation-experiments-to-improve-model-accuracy', 'indices': [197, 315]}]
# Hashtags: [{'hashtag': 'KNIMESummit2018', 'indices': [318, 334]}, {'hashtag': 'OpenSource', 'indices': [335, 346]}]

# %%
# Getting all friends or followers for a user
from sys import maxsize

def get_friends_followers_ids(twitter_api, screen_name=None, user_id=None,
                              friends_limit=maxsize, followers_limit=maxsize):
    
    # Must have either screen_name or user_id (logical xor)
    assert (screen_name != None) != (user_id != None), \
    "Must have screen_name or user_id, but not both"
    
    # See https://dev.twitter.com/docs/api/1.1/get/friends/ids and
    # https://dev.twitter.com/docs/api/1.1/get/followers/ids for details
    # on API parameters
    
    get_friends_ids = partial(make_twitter_request, twitter_api.friends.ids, 
                              count=5000)
    get_followers_ids = partial(make_twitter_request, twitter_api.followers.ids, 
                                count=5000)

    friends_ids, followers_ids = [], []
    
    for twitter_api_func, limit, ids, label in [
                    [get_friends_ids, friends_limit, friends_ids, "friends"], 
                    [get_followers_ids, followers_limit, followers_ids, "followers"]
                ]:
        
        if limit == 0: continue
        
        cursor = -1
        while cursor != 0:
        
            if screen_name: 
                response = twitter_api_func(screen_name=screen_name, cursor=cursor)
            else: # user_id
                response = twitter_api_func(user_id=user_id, cursor=cursor)

            if response is not None:
                ids += response['ids']
                cursor = response['next_cursor']
        
            print('Fetched {0} total {1} ids for {2}'.format(len(ids), 
                                                    label, (user_id or screen_name)))
        
            if len(ids) >= limit or response is None:
                break

    return friends_ids[:friends_limit], followers_ids[:followers_limit]


twitter_api = oauth_login()

friends_ids, followers_ids = get_friends_followers_ids(twitter_api, 
                                                       screen_name="deanabb", 
                                                       friends_limit=10, 
                                                       followers_limit=10)

print (friends_ids)
print (followers_ids)
# Out:
# Fetched 249 total friends ids for deanabb
# Fetched 4705 total followers ids for deanabb
# [1449955262, 5518682, 829108462244093952, 59481779, 2479516946, 4855085037, 913079610887294976, 763866327849238528, 722214536460173312, 4361928854]
# [506089354, 3228024243, 826399829093924864, 955384264442466304, 350335365, 157526667, 857586472718880768, 955297146512838656, 955271968940490752, 4466770816]

# %%
# Analyzing a user's friends and followers
def setwise_friends_followers_analysis(screen_name, friends_ids, followers_ids):
    
    friends_ids, followers_ids = set(friends_ids), set(followers_ids)
    
    print ('{0} is following {1}'.format(screen_name, len(friends_ids)))

    print ('{0} is being followed by {1}'.format(screen_name, len(followers_ids)))
    
    print ('{0} of {1} are not following {2} back'.format(
            len(friends_ids.difference(followers_ids)), 
            len(friends_ids), screen_name))
    
    print ('{0} of {1} are not being followed back by {2}'.format(
            len(followers_ids.difference(friends_ids)), 
            len(followers_ids), screen_name))
    
    print ('{0} has {1} mutual friends'.format(
            screen_name, len(friends_ids.intersection(followers_ids))))


screen_name = "deanabb"

twitter_api = oauth_login()

friends_ids, followers_ids = get_friends_followers_ids(twitter_api, 
                                                       screen_name=screen_name)
setwise_friends_followers_analysis(screen_name, friends_ids, followers_ids)
# Out:
# Fetched 249 total friends ids for deanabb
# Fetched 4705 total followers ids for deanabb
# deanabb is following 249
# deanabb is being followed by 4705
# 76 of 249 are not following deanabb back
# 4532 of 4705 are not being followed back by deanabb
# deanabb has 173 mutual friends

# %%
#Analyzing tweet content
def analyze_tweet_content(statuses):
    
    if len(statuses) == 0:
        print ("No statuses to analyze")
        return
    
    # A nested helper function for computing lexical diversity
    def lexical_diversity(tokens):
        return 1.0*len(set(tokens))/len(tokens) 
    
    # A nested helper function for computing the average number of words per tweet
    def average_words(statuses):
        total_words = sum([ len(s.split()) for s in statuses ]) 
        return 1.0*total_words/len(statuses)

    status_texts = [ status['text'] for status in statuses ]
    screen_names, hashtags, urls, media, _ = extract_tweet_entities(statuses)
    
    # Compute a collection of all words from all tweets
    words = [ w 
          for t in status_texts 
              for w in t.split() ]
    
    print ("Lexical diversity (words):", lexical_diversity(words))
    print ("Lexical diversity (screen names):", lexical_diversity(screen_names))
    print ("Lexical diversity (hashtags):", lexical_diversity(hashtags))
    print ("Averge words per tweet:", average_words(status_texts))

    
# Sample usage

q = 'datascience'
twitter_api = oauth_login()
search_results = twitter_search(twitter_api, q)

analyze_tweet_content(search_results)
# Out:
# Lexical diversity (words): 0.393154486586494
# Lexical diversity (screen names): 0.4426229508196721
# Lexical diversity (hashtags): 0.27419354838709675
# Averge words per tweet: 16.37878787878788

# %%
# Analyzing a user's favorite tweets
def analyze_favorites(twitter_api, screen_name, entity_threshold=2):
    
    favs = twitter_api.favorites.list(screen_name=screen_name, count=200)
    print ("Number of favorites:", len(favs))
    
    # Figure out what some of the common entities are, if any, in the content
    
    common_entities = get_common_tweet_entities(favs, 
                                                entity_threshold=entity_threshold)
    
    # Use PrettyTable to create a nice tabular display
    
    pt = PrettyTable(field_names=['Entity', 'Count']) 
    [ pt.add_row(kv) for kv in common_entities ]
    pt.align['Entity'], pt.align['Count'] = 'l', 'r' # Set column alignment
    
    print
    print ("Common entities in favorites...")
    print (pt)
    
    
    # Print out some other stats
    print
    print ("Some statistics about the content of the favorities...")
    print
    analyze_tweet_content(favs)
    
    # Could also start analyzing link content or summarized link content, and more.

# Sample usage

twitter_api = oauth_login()
analyze_favorites(twitter_api, "deanabb")
# Out:
# Number of favorites: 199
# Common entities in favorites...
# +---------------------------------------------------------------------------+-------+
# | Entity                                                                    | Count |
# +---------------------------------------------------------------------------+-------+
# | deanabb                                                                   |    83 |
# | pawcon                                                                    |    23 |
# | DataScience                                                               |    23 |
# | BigData                                                                   |    14 |
# | AI                                                                        |    11 |
# | MachineLearning                                                           |    11 |
# | datascience                                                               |     8 |
# | SmarterHQ                                                                 |     8 |
# | johnelder4                                                                |     8 |
# | analytics                                                                 |     6 |
# | HR                                                                        |     6 |
# | TDWI                                                                      |     5 |
# | OsborneOsborne                                                            |     5 |
# | PAWWorkforce                                                              |     5 |
# | PredictiveAnalytics                                                       |     5 |
# | PredictiveModeling                                                        |     4 |
# | workshops                                                                 |     4 |
# | knime                                                                     |     4 |
# | KNIMESummit2017                                                           |     4 |
# | LasVegas                                                                  |     4 |
# | KNIME                                                                     |     4 |
# | DataScientist                                                             |     4 |
# | Analytics                                                                 |     3 |
# | Berlin                                                                    |     3 |
# | bigdata                                                                   |     3 |
# | datscience                                                                |     3 |
# | https://www.knime.org/spring-summit2017#summit-agenda                     |     3 |
# | KNIMEFallSummit16                                                         |     3 |
# | predictanalytic                                                           |     3 |
# | KirkDBorne                                                                |     3 |
# | KNIMEsummit2017                                                           |     3 |
# | eMetrics                                                                  |     3 |
# | pasharoberts                                                              |     3 |
# | SASsoftware                                                               |     2 |
# | bobgrossman                                                               |     2 |
# | Predictive                                                                |     2 |
# | PAWChicago                                                                |     2 |
# | TalentAnalytics                                                           |     2 |
# | Chicago                                                                   |     2 |
# | abdsc                                                                     |     2 |
# | rstats                                                                    |     2 |
# | BehavioralAnalytics                                                       |     2 |
# | https://martechexec.com/article/the-impact-of-ai-on-modern-marketing.html |     2 |
# | predictive                                                                |     2 |
# | datablending                                                              |     2 |
# | alegg                                                                     |     2 |
# | MarTechExec                                                               |     2 |
# | Python                                                                    |     2 |
# | DataPrep                                                                  |     2 |
# | kdnuggets                                                                 |     2 |
# | passbac                                                                   |     2 |
# | Anaheim                                                                   |     2 |
# | martech                                                                   |     2 |
# | eTailWest                                                                 |     2 |
# | h2oai                                                                     |     2 |
# | omnichannel                                                               |     2 |
# | TechPointInd                                                              |     2 |
# | PAWCON                                                                    |     2 |
# | Marketing                                                                 |     2 |
# | cmswire                                                                   |     2 |
# | dataviz                                                                   |     2 |
# | datamining                                                                |     2 |
# | Adweek                                                                    |     2 |
# +---------------------------------------------------------------------------+-------+
# Some statistics about the content of the favorities...
# Lexical diversity (words): 0.5748380497783839
# Lexical diversity (screen names): 0.483739837398374
# Lexical diversity (hashtags): 0.4782608695652174
# Averge words per tweet: 14.738693467336683

# %%
#Saving and accessing JSON data with MongoDB
import pymongo 

def save_to_mongo(data, mongo_db, mongo_db_coll):
    
    # Connects to the MongoDB server running on 
    # localhost:27017 by default
    
    client = pymongo.MongoClient("localhost", 27017)
    
    # Get a reference to a particular database
    
    db = client[mongo_db]
    
    # Reference a particular collection in the database
    
    coll = db[mongo_db_coll]
    
    # Perform a bulk insert and  return the IDs
    
    return coll.insert(data)

def load_from_mongo(mongo_db, mongo_db_coll, return_cursor=False,
                    criteria=None, projection=None):
    
    # Optionally, use criteria and projection to limit the data that is 
    # returned as documented in 
    # http://docs.mongodb.org/manual/reference/method/db.collection.find/
    
    # Consider leveraging MongoDB's aggregations framework for more 
    # sophisticated queries.
    
    client = pymongo.MongoClient("localhost", 27017)
    db = client[mongo_db]
    coll = db[mongo_db_coll]
    
    if criteria is None:
        criteria = {}
    
    if projection is None:
        cursor = coll.find(criteria)
    else:
        cursor = coll.find(criteria, projection)

    # Returning a cursor is recommended for large amounts of data
    
    if return_cursor:
        return cursor
    else:
        return [ item for item in cursor ]

# Sample usage

q = 'bitcoin'

twitter_api = oauth_login()
results = twitter_search(twitter_api, q, max_results=10)

save_to_mongo(results, 'search_results', q)

load_from_mongo('search_results', q, criteria = {'retweet_count':{'$gt':10}})
# Out:
# f:\Users\Tahar\Anacondanew\envs\ztdl\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# [{'_id': ObjectId('5a668665f550052a34e978b3'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:32 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2244340904,
#      'id_str': '2244340904',
#      'indices': [3, 10],
#      'name': 'Recode',
#      'screen_name': 'Recode'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603120813469696,
#   'id_str': '955603120813469696',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 24,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Jan 22 21:17:54 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/955550110422913025',
#       'indices': [115, 138],
#       'url': 'https://t.co/TrH5KHb2da'}],
#     'user_mentions': []},
#    'favorite_count': 31,
#    'favorited': False,
#    'geo': None,
#    'id': 955550110422913025,
#    'id_str': '955550110422913025',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 24,
#    'retweeted': False,
#    'source': '<a href="http://www.voxmedia.com" rel="nofollow">Vox Media</a>',
#    'text': 'Bitcoin broker Coinbase booked $1 billion in revenue last year — so the company has told hovering VCs to back off… https://t.co/TrH5KHb2da',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Dec 13 19:03:27 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Tech and business news, live. Sign up for our daily newsletter: https://t.co/tUx3axo4pW',
#     'entities': {'description': {'urls': [{'display_url': 'bit.ly/2h8uv8u',
#         'expanded_url': 'http://bit.ly/2h8uv8u',
#         'indices': [64, 87],
#         'url': 'https://t.co/tUx3axo4pW'}]},
#      'url': {'urls': [{'display_url': 'recode.net',
#         'expanded_url': 'http://recode.net',
#         'indices': [0, 23],
#         'url': 'https://t.co/trFjw6yxoC'}]}},
#     'favourites_count': 2099,
#     'follow_request_sent': False,
#     'followers_count': 341107,
#     'following': False,
#     'friends_count': 620,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2244340904,
#     'id_str': '2244340904',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 10874,
#     'location': 'San Francisco, CA',
#     'name': 'Recode',
#     'notifications': False,
#     'profile_background_color': 'CE0203',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000159765723/kvqTBYQ-.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000159765723/kvqTBYQ-.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244340904/1515110695',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/729365899828989952/o0AuZCNW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/729365899828989952/o0AuZCNW_normal.jpg',
#     'profile_link_color': 'E62E25',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F3F3F3',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'Recode',
#     'statuses_count': 35942,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/trFjw6yxoC',
#     'utc_offset': -28800,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @Recode: Bitcoin broker Coinbase booked $1 billion in revenue last year — so the company has told hovering VCs to back off https://t.co/…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Sep 12 03:55:34 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '@amorstil, @claydotio, @utaustin grad. always learning and searching for adventure.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'robertleung.me',
#        'expanded_url': 'http://robertleung.me',
#        'indices': [0, 23],
#        'url': 'https://t.co/vCigPCiA5A'}]}},
#    'favourites_count': 4553,
#    'follow_request_sent': False,
#    'followers_count': 143,
#    'following': False,
#    'friends_count': 507,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 372099712,
#    'id_str': '372099712',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 17,
#    'location': 'Austin, TX',
#    'name': 'Robert Leung',
#    'notifications': False,
#    'profile_background_color': 'BADFCD',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/372099712/1400476744',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/814688127637975040/rD_WKMeL_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/814688127637975040/rD_WKMeL_normal.jpg',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'F2E195',
#    'profile_sidebar_fill_color': 'FFF7CC',
#    'profile_text_color': '0C3E53',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'RobertWLeung',
#    'statuses_count': 4933,
#    'time_zone': 'Central Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/vCigPCiA5A',
#    'utc_offset': -21600,
#    'verified': False}},
#  {'_id': ObjectId('5a668665f550052a34e978b5'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:32 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'on.ft.com/2E0Sdf3',
#      'expanded_url': 'http://on.ft.com/2E0Sdf3',
#      'indices': [71, 94],
#      'url': 'https://t.co/I6EObI6jfc'}],
#    'user_mentions': [{'id': 4898091,
#      'id_str': '4898091',
#      'indices': [3, 18],
#      'name': 'Financial Times',
#      'screen_name': 'FinancialTimes'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603117789335552,
#   'id_str': '955603117789335552',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 11,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Jan 23 00:33:05 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'on.ft.com/2E0Sdf3',
#       'expanded_url': 'http://on.ft.com/2E0Sdf3',
#       'indices': [51, 74],
#       'url': 'https://t.co/I6EObI6jfc'}],
#     'user_mentions': []},
#    'favorite_count': 14,
#    'favorited': False,
#    'geo': None,
#    'id': 955599229610811392,
#    'id_str': '955599229610811392',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 11,
#    'retweeted': False,
#    'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#    'text': 'Japan bitcoin bourse group stages Europe expansion https://t.co/I6EObI6jfc',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 16 16:54:19 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The best of FT journalism, including breaking news and insight',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'ft.com',
#         'expanded_url': 'http://www.ft.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/177fJYDjdc'}]}},
#     'favourites_count': 9,
#     'follow_request_sent': False,
#     'followers_count': 5970994,
#     'following': False,
#     'friends_count': 819,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 4898091,
#     'id_str': '4898091',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 38199,
#     'location': 'London, UK',
#     'name': 'Financial Times',
#     'notifications': False,
#     'profile_background_color': 'FFF1E0',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/234729379/ft-twitter-back.gif',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/234729379/ft-twitter-back.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4898091/1515062434',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/931161479398686721/FI3te2Sw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/931161479398686721/FI3te2Sw_normal.jpg',
#     'profile_link_color': '9E2F50',
#     'profile_sidebar_border_color': 'A7A59B',
#     'profile_sidebar_fill_color': 'E9DECF',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'FinancialTimes',
#     'statuses_count': 218024,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'http://t.co/177fJYDjdc',
#     'utc_offset': 0,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @FinancialTimes: Japan bitcoin bourse group stages Europe expansion https://t.co/I6EObI6jfc',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 18 01:05:08 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Moroccan. Here for a few decades tops. Poke excessive power/wealth unchecked. CryptoBeliever. Raise chickens, grow crops, and trade for more $BTC to HODL.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1750,
#    'follow_request_sent': False,
#    'followers_count': 6744,
#    'following': False,
#    'friends_count': 2535,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 40777562,
#    'id_str': '40777562',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 159,
#    'location': 'Washington, DC',
#    'name': 'Zineb Belmkaddem',
#    'notifications': False,
#    'profile_background_color': '352726',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40777562/1510291194',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/784495714164289536/6xuIVO4R_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/784495714164289536/6xuIVO4R_normal.jpg',
#    'profile_link_color': 'D02B55',
#    'profile_sidebar_border_color': '829D5E',
#    'profile_sidebar_fill_color': '99CC33',
#    'profile_text_color': '3E4415',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Onlyzineb',
#    'statuses_count': 9280,
#    'time_zone': 'Casablanca',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 0,
#    'verified': False}},
#  {'_id': ObjectId('5a668665f550052a34e978ba'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:29 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3375167474,
#      'id_str': '3375167474',
#      'indices': [3, 16],
#      'name': 'PunchesBears ㅎ㉨ㅎ',
#      'screen_name': 'punchesbears'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603106884014080,
#   'id_str': '955603106884014080',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 67,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Jan 22 22:53:23 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 319,
#    'favorited': False,
#    'geo': None,
#    'id': 955574141284790272,
#    'id_str': '955574141284790272',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 67,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'bitcoin miners...since the price crashed can you please give us back all of the graphics cards now?',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Aug 28 22:42:10 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Deep Learning, Procedural animation, VR, & vidya games. Working on Wreckoons. A game about stealing trash & being an asshole. Profile doodle by @buenothebear',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'PunchesBears.com',
#         'expanded_url': 'http://PunchesBears.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/xiA5ySq00e'}]}},
#     'favourites_count': 9769,
#     'follow_request_sent': False,
#     'followers_count': 39616,
#     'following': False,
#     'friends_count': 705,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 3375167474,
#     'id_str': '3375167474',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 523,
#     'location': 'punchesbears at gmail dot com',
#     'name': 'PunchesBears ㅎ㉨ㅎ',
#     'notifications': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3375167474/1513502412',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/867532273293373442/cYyF0yky_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/867532273293373442/cYyF0yky_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'punchesbears',
#     'statuses_count': 11437,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/xiA5ySq00e',
#     'utc_offset': -28800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @punchesbears: bitcoin miners...since the price crashed can you please give us back all of the graphics cards now?',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Sep 14 06:34:12 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Animator. Nerd. Lover of Food. Player of Video Games. Quite Queer. My shitty opinions are my own. 🏳️\u200d🌈🇺🇸🇲🇽',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'youtube.com/c/gastlichu',
#        'expanded_url': 'https://www.youtube.com/c/gastlichu',
#        'indices': [0, 23],
#        'url': 'https://t.co/bJEukGCt9r'}]}},
#    'favourites_count': 18542,
#    'follow_request_sent': False,
#    'followers_count': 676,
#    'following': False,
#    'friends_count': 185,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 373226763,
#    'id_str': '373226763',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 50,
#    'location': 'San Diego, CA',
#    'name': 'José Angel',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/934630520704528384/iHVCkykP_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/934630520704528384/iHVCkykP_normal.jpg',
#    'profile_link_color': 'F745CA',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'gastlichu',
#    'statuses_count': 302,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'regular',
#    'url': 'https://t.co/bJEukGCt9r',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'_id': ObjectId('5a668665f550052a34e978bb'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:28 +0000 2018',
#   'entities': {'hashtags': [{'indices': [19, 37], 'text': 'IStillHaventFound'},
#     {'indices': [50, 54], 'text': 'FBI'},
#     {'indices': [71, 84], 'text': 'FindTheTexts'},
#     {'indices': [101, 109], 'text': 'Bitcoin'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 35301840,
#      'id_str': '35301840',
#      'indices': [3, 17],
#      'name': 'ladynada',
#      'screen_name': 'heartdaughter'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603104325611520,
#   'id_str': '955603104325611520',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 27,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Jan 22 18:51:46 +0000 2018',
#    'entities': {'hashtags': [{'indices': [0, 18], 'text': 'IStillHaventFound'},
#      {'indices': [31, 35], 'text': 'FBI'},
#      {'indices': [52, 65], 'text': 'FindTheTexts'},
#      {'indices': [82, 90], 'text': 'Bitcoin'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/955513337063837696',
#       'indices': [121, 144],
#       'url': 'https://t.co/V1bhKvx4UG'}],
#     'user_mentions': []},
#    'favorite_count': 34,
#    'favorited': False,
#    'geo': None,
#    'id': 955513337063837696,
#    'id_str': '955513337063837696',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 27,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '#IStillHaventFound The Missing #FBI Text Messages!\n\n#FindTheTexts!!\n\nGet .50 mBTC #Bitcoin &amp; Mining Software all FR… https://t.co/V1bhKvx4UG',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Apr 25 20:27:12 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Servant of the Living God, Me114 on GLP, prophet/teacher giving prophetic words from Father God, aware of whatsup',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'world.std.com/~snet/THE_TRUE…',
#         'expanded_url': 'http://world.std.com/~snet/THE_TRUE_COSMOGENY.htm',
#         'indices': [0, 23],
#         'url': 'https://t.co/H35GeV1HsR'}]}},
#     'favourites_count': 9442,
#     'follow_request_sent': False,
#     'followers_count': 3139,
#     'following': False,
#     'friends_count': 2253,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 35301840,
#     'id_str': '35301840',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 111,
#     'location': 'New England',
#     'name': 'ladynada',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/35301840/1473266377',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/183346324/rainbowdragon_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/183346324/rainbowdragon_normal.jpg',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'heartdaughter',
#     'statuses_count': 21411,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/H35GeV1HsR',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @heartdaughter: #IStillHaventFound The Missing #FBI Text Messages!\n\n#FindTheTexts!!\n\nGet .50 mBTC #Bitcoin &amp; Mining Software all FREE -…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jan 05 21:14:39 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': "I'm a #TRUMPLICAN! #DEPLORABLE #ALWAYSTRUMPER despite ridicule of friends & peers #MAGA I pray that God CONTINUES to Bless America!!!",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 6193,
#    'follow_request_sent': False,
#    'followers_count': 1814,
#    'following': False,
#    'friends_count': 2950,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 817117127085817856,
#    'id_str': '817117127085817856',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 6,
#    'location': 'Washington, DC',
#    'name': 'Trump Lives MATTER!!',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/817117127085817856/1499206444',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/817123867655278592/QD5gMcpt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817123867655278592/QD5gMcpt_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'kimnovakb',
#    'statuses_count': 6861,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('5a668665f550052a34e978bc'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:28 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1297695480,
#      'id_str': '1297695480',
#      'indices': [3, 16],
#      'name': 'หมี🐻ปาก🐶',
#      'screen_name': 'dogmouthbear'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603102534483968,
#   'id_str': '955603102534483968',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'th',
#   'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 8267,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Jan 21 14:47:18 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/955089427381985283',
#       'indices': [115, 138],
#       'url': 'https://t.co/HE8lKSa8LE'}],
#     'user_mentions': []},
#    'favorite_count': 744,
#    'favorited': False,
#    'geo': None,
#    'id': 955089427381985283,
#    'id_str': '955089427381985283',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'th',
#    'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 8267,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ… https://t.co/HE8lKSa8LE',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Mar 25 05:02:14 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'เขียนนิยายดี แต่นิสัยไม่ได้ดีเหมือนนิยาย/ #แต้วมิว ดิ่เอ้อ / เขียน #หม่อมศิริน #แม้นมิ่งยิ่งหล้า และอีกมากมาย/ On going: #พันหมื่นราตรี #ฟิคหมอมิว',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 74160,
#     'follow_request_sent': False,
#     'followers_count': 2755,
#     'following': False,
#     'friends_count': 76,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1297695480,
#     'id_str': '1297695480',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 9,
#     'location': '',
#     'name': 'หมี🐻ปาก🐶',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1297695480/1511108268',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/952222381371662336/Z7aanjT8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/952222381371662336/Z7aanjT8_normal.jpg',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'dogmouthbear',
#     'statuses_count': 86791,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 0,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @dogmouthbear: นั่งกินข้าว อยู่ดีๆโต๊ะข้างๆก็เปิดประเด็นเรื่อง LGBTQ ละอีผช.แบบ "ผมว่ามันผิด มันจะทำให้ประชากรสูญพันธุ์" แล้ว ผญ คือดูอา…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jun 12 02:04:41 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1021,
#    'follow_request_sent': False,
#    'followers_count': 218,
#    'following': False,
#    'friends_count': 380,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 605930488,
#    'id_str': '605930488',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'th',
#    'listed_count': 1,
#    'location': ' Thailand',
#    'name': 'grace',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000091029359/c7d3dd57743f043e41a5546a215ff5d6.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000091029359/c7d3dd57743f043e41a5546a215ff5d6.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/605930488/1453720757',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/943850202582081536/3Gu_GP83_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943850202582081536/3Gu_GP83_normal.jpg',
#    'profile_link_color': 'F5ABB5',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'graceyaeh',
#    'statuses_count': 87165,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('5a668665f550052a34e978c1'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:24 +0000 2018',
#   'entities': {'hashtags': [{'indices': [113, 118], 'text': 'MWAT'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 926439263071326209,
#      'id_str': '926439263071326209',
#      'indices': [3, 19],
#      'name': 'Restart Energy Democracy',
#      'screen_name': 'RestartEnergyio'},
#     {'id': 14511951,
#      'id_str': '14511951',
#      'indices': [87, 96],
#      'name': 'HuffPost',
#      'screen_name': 'HuffPost'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603086277513216,
#   'id_str': '955603086277513216',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 5825,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jan 10 09:45:15 +0000 2018',
#    'entities': {'hashtags': [{'indices': [92, 97], 'text': 'MWAT'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/951027144725073920',
#       'indices': [117, 140],
#       'url': 'https://t.co/RbGVKqkluW'}],
#     'user_mentions': [{'id': 14511951,
#       'id_str': '14511951',
#       'indices': [66, 75],
#       'name': 'HuffPost',
#       'screen_name': 'HuffPost'}]},
#    'favorite_count': 925,
#    'favorited': False,
#    'geo': None,
#    'id': 951027144725073920,
#    'id_str': '951027144725073920',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 5825,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '✨Restart Energy Democracy, the hottest ICO in 2018 is reviewed on @HuffPost. Read about our #MWAT token and all the… https://t.co/RbGVKqkluW',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Nov 03 13:21:47 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "The world's first market-ready blockchain energy trading platform. Supported by the $MWAT token. ICO now on!",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'restartenergy.io',
#         'expanded_url': 'http://www.restartenergy.io',
#         'indices': [0, 23],
#         'url': 'https://t.co/FXahnwaa82'}]}},
#     'favourites_count': 3,
#     'follow_request_sent': False,
#     'followers_count': 12912,
#     'following': False,
#     'friends_count': 100,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 926439263071326209,
#     'id_str': '926439263071326209',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en-gb',
#     'listed_count': 24,
#     'location': 'Bucureşti, România',
#     'name': 'Restart Energy Democracy',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/926439263071326209/1512199808',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/927648736548937730/kCvr_Inr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/927648736548937730/kCvr_Inr_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RestartEnergyio',
#     'statuses_count': 51,
#     'time_zone': 'Bucharest',
#     'translator_type': 'none',
#     'url': 'https://t.co/FXahnwaa82',
#     'utc_offset': 7200,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @RestartEnergyio: ✨Restart Energy Democracy, the hottest ICO in 2018 is reviewed on @HuffPost. Read about our #MWAT token and all the re…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Sep 11 09:44:14 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 65,
#    'follow_request_sent': False,
#    'followers_count': 529,
#    'following': False,
#    'friends_count': 353,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 907177955973050368,
#    'id_str': '907177955973050368',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ru',
#    'listed_count': 0,
#    'location': '',
#    'name': 'Julio Wendling',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/934590872762683392/_i0vt8j2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/934590872762683392/_i0vt8j2_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'mimosafanfare',
#    'statuses_count': 187,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'_id': ObjectId('5a668665f550052a34e978c3'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:23 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [{'indices': [14, 18], 'text': 'DNR'}],
#    'urls': [],
#    'user_mentions': [{'id': 792539082869968896,
#      'id_str': '792539082869968896',
#      'indices': [3, 12],
#      'name': 'Carsen Klock',
#      'screen_name': 'carsenjk'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603083362320384,
#   'id_str': '955603083362320384',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 124,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Jan 22 20:17:26 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [{'indices': [0, 4], 'text': 'DNR'}],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/955534893378781184',
#       'indices': [117, 140],
#       'url': 'https://t.co/vqpUxEmuj7'}],
#     'user_mentions': []},
#    'favorite_count': 68,
#    'favorited': False,
#    'geo': None,
#    'id': 955534893378781184,
#    'id_str': '955534893378781184',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 124,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': '$DNR Cold Storage Giveaway #2! I will be giving away a couple prototype Denarius Cold Storage Cards that I have bee… https://t.co/vqpUxEmuj7',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Oct 30 01:30:17 +0000 2016',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Hey! I'm Carsen. I'm a developer. I love development, design, and bleeding-edge tech. Bitcoin, Denarius, cryptocurrency, and a whole lot more. $crypto",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'carsencustoms.com',
#         'expanded_url': 'http://carsencustoms.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/1phIqE0SsG'}]}},
#     'favourites_count': 2404,
#     'follow_request_sent': False,
#     'followers_count': 3704,
#     'following': False,
#     'friends_count': 4992,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 792539082869968896,
#     'id_str': '792539082869968896',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 48,
#     'location': 'United States',
#     'name': 'Carsen Klock',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/792539082869968896/1477792215',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/903837408327639040/Ln7L4hhX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/903837408327639040/Ln7L4hhX_normal.jpg',
#     'profile_link_color': '333333',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'carsenjk',
#     'statuses_count': 749,
#     'time_zone': 'Mountain Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/1phIqE0SsG',
#     'utc_offset': -25200,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @carsenjk: $DNR Cold Storage Giveaway #2! I will be giving away a couple prototype Denarius Cold Storage Cards that I have been working…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 30 03:07:29 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 52,
#    'follow_request_sent': False,
#    'followers_count': 14,
#    'following': False,
#    'friends_count': 222,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 781691912868794368,
#    'id_str': '781691912868794368',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'zh-CN',
#    'listed_count': 2,
#    'location': '',
#    'name': 'victor',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/923815431009214467/TfecIIov_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/923815431009214467/TfecIIov_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'KillerqoopMotor',
#    'statuses_count': 149,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('5a668665f550052a34e978c4'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 00:48:22 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 756475,
#      'id_str': '756475',
#      'indices': [3, 12],
#      'name': 'Annalee Newitz',
#      'screen_name': 'Annaleen'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955603076978634752,
#   'id_str': '955603076978634752',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 28,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Jan 22 21:48:15 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/955557749303078912',
#       'indices': [116, 139],
#       'url': 'https://t.co/CJf9h8Z2rX'}],
#     'user_mentions': []},
#    'favorite_count': 121,
#    'favorited': False,
#    'geo': None,
#    'id': 955557749303078912,
#    'id_str': '955557749303078912',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 28,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': "I feel like we're headed for some barely imaginable crisis that combines RU-IRA, quantum computing, Crispr-enabled… https://t.co/CJf9h8Z2rX",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Feb 08 00:59:42 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Writing some books about science and history. Author of Autonomous. Founder of io9. Editor-at-large for Ars Technica. Eater of noodles. She/they.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'techsploitation.com',
#         'expanded_url': 'http://www.techsploitation.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/1UHHgAIFkS'}]}},
#     'favourites_count': 35175,
#     'follow_request_sent': False,
#     'followers_count': 30683,
#     'following': False,
#     'friends_count': 1963,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 756475,
#     'id_str': '756475',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1798,
#     'location': 'California',
#     'name': 'Annalee Newitz',
#     'notifications': False,
#     'profile_background_color': 'E56A34',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/54100791/city_sea_a_03c.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/54100791/city_sea_a_03c.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/756475/1392875252',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/682633300972732416/fgsrChyu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/682633300972732416/fgsrChyu_normal.jpg',
#     'profile_link_color': '7A440A',
#     'profile_sidebar_border_color': '87BC44',
#     'profile_sidebar_fill_color': '4479D4',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Annaleen',
#     'statuses_count': 33985,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/1UHHgAIFkS',
#     'utc_offset': -28800,
#     'verified': True}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#   'text': "RT @Annaleen: I feel like we're headed for some barely imaginable crisis that combines RU-IRA, quantum computing, Crispr-enabled eugenics,…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Feb 28 20:20:37 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 188272,
#    'follow_request_sent': False,
#    'followers_count': 593,
#    'following': False,
#    'friends_count': 1432,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 258928741,
#    'id_str': '258928741',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 73,
#    'location': 'Front Range, CO',
#    'name': 'A.P. Brown',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/258928741/1496180948',
# ...
#      'id_str': '741395708041957376',
#      'indices': [64, 70],
#      'name': 'علي الهاجري',
#      'screen_name': 'ccc8l'},
#     {'id': 3942339207,
#      'id_str': '3942339207',
#      'indices': [71, 80],
#      'name': 'صديان بن شمر 🇸🇦',
#      'screen_name': 'SdyanZzn'},
#     {'id': 417756899,
#      'id_str': '417756899',
#      'indices': [81, 92],
#      'name': 'Ⓜ️عبدالله آل سعد🇸🇦',
#      'screen_name': 'A_BINSAAD_'},
#     {'id': 759976826,
#      'id_str': '759976826',
#      'indices': [93, 106],
#      'name': 'ابو حسين',
#      'screen_name': 'Abu_Husssein'},
#     {'id': 293690734,
#      'id_str': '293690734',
#      'indices': [107, 113],
#      'name': '🇸🇦Fzz🚫💀452',
#      'screen_name': 'd_77b'},
#     {'id': 2898296389,
#      'id_str': '2898296389',
#      'indices': [114, 130],
#      'name': 'محمد الشمراني',
#      'screen_name': 'alshamrani14151'},
#     {'id': 875657124885528576,
#      'id_str': '875657124885528576',
#      'indices': [131, 138],
#      'name': 'الجيش الالكتروني🚫',
#      'screen_name': '7_b_60'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955638794635497472,
#   'id_str': '955638794635497472',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 31,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Jan 18 01:09:34 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/953796474416058369',
#       'indices': [116, 139],
#       'url': 'https://t.co/lLIhicuLFg'}],
#     'user_mentions': [{'id': 2684360065,
#       'id_str': '2684360065',
#       'indices': [0, 6],
#       'name': 'داعم #الجيش_السلماني',
#       'screen_name': 'MGWVc'},
#      {'id': 843036744673124352,
#       'id_str': '843036744673124352',
#       'indices': [7, 16],
#       'name': 'سيمفونيـہ',
#       'screen_name': 'semfo990'},
#      {'id': 754980346878386176,
#       'id_str': '754980346878386176',
#       'indices': [17, 28],
#       'name': 'وطن سلمآن💚👑..',
#       'screen_name': 'lammia2015'},
#      {'id': 3236808286,
#       'id_str': '3236808286',
#       'indices': [29, 38],
#       'name': 'الجوري 🇸🇦💚🇸🇦',
#       'screen_name': 'goorryyi'},
#      {'id': 755477823469588480,
#       'id_str': '755477823469588480',
#       'indices': [39, 47],
#       'name': 'محب ولي العهد',
#       'screen_name': 'mmm4450'},
#      {'id': 741395708041957376,
#       'id_str': '741395708041957376',
#       'indices': [48, 54],
#       'name': 'علي الهاجري',
#       'screen_name': 'ccc8l'},
#      {'id': 3942339207,
#       'id_str': '3942339207',
#       'indices': [55, 64],
#       'name': 'صديان بن شمر 🇸🇦',
#       'screen_name': 'SdyanZzn'},
#      {'id': 417756899,
#       'id_str': '417756899',
#       'indices': [65, 76],
#       'name': 'Ⓜ️عبدالله آل سعد🇸🇦',
#       'screen_name': 'A_BINSAAD_'},
#      {'id': 759976826,
#       'id_str': '759976826',
#       'indices': [77, 90],
#       'name': 'ابو حسين',
#       'screen_name': 'Abu_Husssein'},
#      {'id': 293690734,
#       'id_str': '293690734',
#       'indices': [91, 97],
#       'name': '🇸🇦Fzz🚫💀452',
#       'screen_name': 'd_77b'},
#      {'id': 2898296389,
#       'id_str': '2898296389',
#       'indices': [98, 114],
#       'name': 'محمد الشمراني',
#       'screen_name': 'alshamrani14151'}]},
#    'favorite_count': 8,
#    'favorited': False,
#    'geo': None,
#    'id': 953796474416058369,
#    'id_str': '953796474416058369',
#    'in_reply_to_screen_name': 'MGWVc',
#    'in_reply_to_status_id': 953753054947442693,
#    'in_reply_to_status_id_str': '953753054947442693',
#    'in_reply_to_user_id': 2684360065,
#    'in_reply_to_user_id_str': '2684360065',
#    'is_quote_status': False,
#    'lang': 'und',
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 31,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': '@MGWVc @semfo990 @lammia2015 @goorryyi @mmm4450 @ccc8l @SdyanZzn @A_BINSAAD_ @Abu_Husssein @d_77b @alshamrani14151… https://t.co/lLIhicuLFg',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jan 01 04:30:42 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#السلماني_للترند\n\u200e\u200e\u200e\u200e\u200e#TT4F\n\u200e\u200e\u200e#1DDrive\n\u200e\u200e\u200e\u200e\u200e\u200e\u200e#جهينه_للدعم\n#FF #Rt #Up #Rt_Up\n\u200e\u200e\u200e\u200e\u200e\u200e#MFTGAIN\n\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e#TMSTALLION\n\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e#MGWV \u200e#TeamSil\nاهلا',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'instagram.com/royalsbachl',
#         'expanded_url': 'http://instagram.com/royalsbachl',
#         'indices': [0, 23],
#         'url': 'https://t.co/1y0lQcGHIf'}]}},
#     'favourites_count': 1751,
#     'follow_request_sent': False,
#     'followers_count': 10868,
#     'following': False,
#     'friends_count': 10965,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 1051817869,
#     'id_str': '1051817869',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'ar',
#     'listed_count': 37,
#     'location': 'جدة, المملكة العربية السعودية',
#     'name': '#RT رتويت ومغرد سعودي',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051817869/1512613805',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/950555212451807232/V0tfrBYU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/950555212451807232/V0tfrBYU_normal.jpg',
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'MGWV_Vinny',
#     'statuses_count': 70234,
#     'time_zone': 'Riyadh',
#     'translator_type': 'none',
#     'url': 'https://t.co/1y0lQcGHIf',
#     'utc_offset': 10800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @MGWV_Vinny: @MGWVc @semfo990 @lammia2015 @goorryyi @mmm4450 @ccc8l @SdyanZzn @A_BINSAAD_ @Abu_Husssein @d_77b @alshamrani14151 @7_b_60…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jan 01 04:30:42 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#السلماني_للترند\n\u200e\u200e\u200e\u200e\u200e#TT4F\n\u200e\u200e\u200e#1DDrive\n\u200e\u200e\u200e\u200e\u200e\u200e\u200e#جهينه_للدعم\n#FF #Rt #Up #Rt_Up\n\u200e\u200e\u200e\u200e\u200e\u200e#MFTGAIN\n\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e#TMSTALLION\n\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e\u200e#MGWV \u200e#TeamSil\nاهلا',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'instagram.com/royalsbachl',
#        'expanded_url': 'http://instagram.com/royalsbachl',
#        'indices': [0, 23],
#        'url': 'https://t.co/1y0lQcGHIf'}]}},
#    'favourites_count': 1751,
#    'follow_request_sent': False,
#    'followers_count': 10868,
#    'following': False,
#    'friends_count': 10965,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 1051817869,
#    'id_str': '1051817869',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ar',
#    'listed_count': 37,
#    'location': 'جدة, المملكة العربية السعودية',
#    'name': '#RT رتويت ومغرد سعودي',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051817869/1512613805',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/950555212451807232/V0tfrBYU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/950555212451807232/V0tfrBYU_normal.jpg',
#    'profile_link_color': 'F58EA8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'MGWV_Vinny',
#    'statuses_count': 70234,
#    'time_zone': 'Riyadh',
#    'translator_type': 'none',
#    'url': 'https://t.co/1y0lQcGHIf',
#    'utc_offset': 10800,
#    'verified': False}},
#  {'_id': ObjectId('5a66a7cef550054f585191ec'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Jan 23 03:10:17 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 116766613,
#      'id_str': '116766613',
#      'indices': [3, 10],
#      'name': 'Vili Lehdonvirta',
#      'screen_name': 'ViliLe'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 955638793566150656,
#   'id_str': '955638793566150656',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 17,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Jan 21 14:54:59 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/955091359983161344',
#       'indices': [117, 140],
#       'url': 'https://t.co/XbBM6anpdI'}],
#     'user_mentions': []},
#    'favorite_count': 30,
#    'favorited': False,
#    'geo': None,
#    'id': 955091359983161344,
#    'id_str': '955091359983161344',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 17,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '“No one, at this stage, realistically believes that Tether is receiving $100 million a day in customer deposits”. I… https://t.co/XbBM6anpdI',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Feb 23 14:22:25 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Economic sociologist, Oxford Internet Institute. Principal investigator, @iLabourProject. Author, Virtual Economies: Design and Analysis https://t.co/O9otsh9neb',
#     'entities': {'description': {'urls': [{'display_url': 'amzn.to/1qIi3uN',
#         'expanded_url': 'http://amzn.to/1qIi3uN',
#         'indices': [137, 160],
#         'url': 'https://t.co/O9otsh9neb'}]},
#      'url': {'urls': [{'display_url': 'vili.lehdonvirta.com',
#         'expanded_url': 'http://vili.lehdonvirta.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/1xipj5ITEN'}]}},
#     'favourites_count': 12684,
#     'follow_request_sent': False,
#     'followers_count': 4703,
#     'following': False,
#     'friends_count': 956,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 116766613,
#     'id_str': '116766613',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 332,
#     'location': 'Oxford/Helsinki/Tokyo',
#     'name': 'Vili Lehdonvirta',
#     'notifications': False,
#     'profile_background_color': 'EDECE9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/116766613/1439651110',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/645909340965220352/xJjpJhap_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/645909340965220352/xJjpJhap_normal.jpg',
#     'profile_link_color': '088253',
#     'profile_sidebar_border_color': 'D3D2CF',
#     'profile_sidebar_fill_color': 'E3E2DE',
#     'profile_text_color': '634047',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ViliLe',
#     'statuses_count': 7375,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://t.co/1xipj5ITEN',
#     'utc_offset': 0,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @ViliLe: “No one, at this stage, realistically believes that Tether is receiving $100 million a day in customer deposits”. If that’s tru…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jul 16 15:20:57 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Hum Innovation @ Fordham IIHA. Also: https://t.co/l9c4foxdgS . Humanitarian, researcher, negotiator, casual cook and traveler | Views are my own and blah, blah',
#    'entities': {'description': {'urls': [{'display_url': 'hthumanitarians.org',
#        'expanded_url': 'http://hthumanitarians.org',
#        'indices': [37, 60],
#        'url': 'https://t.co/l9c4foxdgS'}]},
#     'url': {'urls': [{'display_url': 'fordham.edu/info/23470/cou…',
#        'expanded_url': 'https://www.fordham.edu/info/23470/courses/9930/data_and_innovation_management_in_humanitarian_actio',
#        'indices': [0, 23],
#        'url': 'https://t.co/3M69mgMZN1'}]}},
#    'favourites_count': 10004,
#    'follow_request_sent': False,
#    'followers_count': 1065,
#    'following': False,
#    'friends_count': 2115,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 167425934,
#    'id_str': '167425934',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 141,
#    'location': 'New York ',
#    'name': 'Giulio Coppi',
#    'notifications': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/434396201408942080/ulDT1w6f.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/434396201408942080/ulDT1w6f.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/167425934/1420832760',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/553639148834152448/gaeNhWV5_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/553639148834152448/gaeNhWV5_normal.jpeg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'GiulioWolfe',
#    'statuses_count': 11730,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/3M69mgMZN1',
#    'utc_offset': -28800,
#    'verified': False}}]

# %%
client = pymongo.MongoClient("localhost", 27017)
dr = client['search_results']
coll = dr[q]

# %%
dr
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'search_results')

# %%
coll
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'search_results'), 'bitcoin')

# %%
# make a query
currr = coll.find({'retweet_count':{'$gt':10}}).limit(1)

# %%
for cur in currr:
    print(cur)
# Out:
# {'_id': ObjectId('5a668665f550052a34e978b3'), 'retweet_count': 24, 'in_reply_to_status_id_str': None, 'text': 'RT @Recode: Bitcoin broker Coinbase booked $1 billion in revenue last year — so the company has told hovering VCs to back off https://t.co/…', 'retweeted': False, 'geo': None, 'favorited': False, 'place': None, 'coordinates': None, 'id': 955603120813469696, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'created_at': 'Tue Jan 23 00:48:32 +0000 2018', 'favorite_count': 0, 'entities': {'symbols': [], 'hashtags': [], 'user_mentions': [{'name': 'Recode', 'id_str': '2244340904', 'indices': [3, 10], 'id': 2244340904, 'screen_name': 'Recode'}], 'urls': []}, 'contributors': None, 'is_quote_status': False, 'in_reply_to_status_id': None, 'id_str': '955603120813469696', 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'retweeted_status': {'retweet_count': 24, 'in_reply_to_status_id_str': None, 'text': 'Bitcoin broker Coinbase booked $1 billion in revenue last year — so the company has told hovering VCs to back off… https://t.co/TrH5KHb2da', 'retweeted': False, 'geo': None, 'favorited': False, 'place': None, 'coordinates': None, 'id': 955550110422913025, 'source': '<a href="http://www.voxmedia.com" rel="nofollow">Vox Media</a>', 'truncated': True, 'created_at': 'Mon Jan 22 21:17:54 +0000 2018', 'favorite_count': 31, 'entities': {'symbols': [], 'hashtags': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/TrH5KHb2da', 'expanded_url': 'https://twitter.com/i/web/status/955550110422913025', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [115, 138]}]}, 'contributors': None, 'is_quote_status': False, 'in_reply_to_status_id': None, 'id_str': '955550110422913025', 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'lang': 'en', 'possibly_sensitive': False, 'user': {'translator_type': 'none', 'has_extended_profile': False, 'location': 'San Francisco, CA', 'followers_count': 341107, 'protected': False, 'favourites_count': 2099, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000159765723/kvqTBYQ-.jpeg', 'notifications': False, 'utc_offset': -28800, 'default_profile': False, 'profile_link_color': 'E62E25', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2244340904/1515110695', 'is_translator': False, 'is_translation_enabled': False, 'profile_background_tile': False, 'listed_count': 10874, 'id': 2244340904, 'profile_text_color': '333333', 'verified': True, 'created_at': 'Fri Dec 13 19:03:27 +0000 2013', 'time_zone': 'Pacific Time (US & Canada)', 'entities': {'description': {'urls': [{'url': 'https://t.co/tUx3axo4pW', 'expanded_url': 'http://bit.ly/2h8uv8u', 'display_url': 'bit.ly/2h8uv8u', 'indices': [64, 87]}]}, 'url': {'urls': [{'url': 'https://t.co/trFjw6yxoC', 'expanded_url': 'http://recode.net', 'display_url': 'recode.net', 'indices': [0, 23]}]}}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/729365899828989952/o0AuZCNW_normal.jpg', 'profile_background_color': 'CE0203', 'url': 'https://t.co/trFjw6yxoC', 'id_str': '2244340904', 'profile_sidebar_fill_color': 'F3F3F3', 'following': False, 'geo_enabled': True, 'lang': 'en', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000159765723/kvqTBYQ-.jpeg', 'friends_count': 620, 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/729365899828989952/o0AuZCNW_normal.jpg', 'default_profile_image': False, 'screen_name': 'Recode', 'description': 'Tech and business news, live. Sign up for our daily newsletter: https://t.co/tUx3axo4pW', 'profile_use_background_image': False, 'profile_sidebar_border_color': 'FFFFFF', 'name': 'Recode', 'statuses_count': 359 ...

# %%
# Count documents resulting from a query
fivestarcount = coll.find({'retweet_count': 10}).count()
print(fivestarcount)
# Out:
# 0

# %%
print('\nThe sum of retween count accross all data grouped by location ')
stargroup=coll.aggregate(
# The Aggregation Pipeline is defined as an array of different operations
[
# The first stage in this pipe is to group data
{ 
    '$project':{
    'geo' :'$user.geo_enabled', 'location':'$user.location', 'retweet':'$retweet_count'}
},
{
    '$group':{'_id':'$location','total':{'$sum':'$retweet'}}
}
# Close the array with the ] tag             
] )
# Print the result
for group in stargroup:
    print(group)
# Out:
# The sum of retween count accross all data grouped by location
# {'total': 0, '_id': 'Cork, Ireland'}
# {'total': 5930, '_id': 'Iraq'}
# {'total': 24, '_id': 'Austin, TX'}
# {'total': 8267, '_id': ' Thailand'}
# {'total': 7, '_id': 'Petro metro'}
# {'total': 38, '_id': 'Washington, DC'}
# {'total': 77051, '_id': ''}
# {'total': 215, '_id': 'Australia'}
# {'total': 0, '_id': 'Moldova'}
# {'total': 2, '_id': 'Miami, Florida'}
# {'total': 1, '_id': 'Worldwide'}
# {'total': 67, '_id': 'San Diego, CA'}
# {'total': 0, '_id': 'Pune, India'}
# {'total': 2, '_id': 'New Orleans, LA'}
# {'total': 1, '_id': 'Montclair, NJ'}
# {'total': 2, '_id': 'New Jersey, USA'}
# {'total': 0, '_id': 'japan'}
# {'total': 31, '_id': 'جدة, المملكة العربية السعودية'}
# {'total': 0, '_id': 'New York'}
# {'total': 28, '_id': 'Front Range, CO'}
# {'total': 0, '_id': 'Sunderland'}
# {'total': 0, '_id': 'North Chicago, IL/ Washington '}
# {'total': 0, '_id': 'California'}
# {'total': 0, '_id': 'Nairobi'}
# {'total': 0, '_id': 'Jacksonville, FL'}
# {'total': 8267, '_id': 'Bangkok, Thailand'}
# {'total': 0, '_id': 'London'}
# {'total': 0, '_id': 'Global'}
# {'total': 197, '_id': 'Chicago / Tokyo'}
# {'total': 53, '_id': 'Coyoacan'}
# {'total': 8267, '_id': 'Thailand'}
# {'total': 15, '_id': 'World'}
# {'total': 1745, '_id': 'Republic of Belarus'}
# {'total': 0, '_id': 'Madrid, Comunidad de Madrid'}
# {'total': 1, '_id': 'Virginia, USA'}
# {'total': 0, '_id': 'Toronto, Ontario, Canada'}
# {'total': 8267, '_id': 'BOICE'}
# {'total': 0, '_id': 'Albuquerque, NM'}
# {'total': 0, '_id': 'Cape Town, South Africa'}
# {'total': 0, '_id': "Wherever I am, it's a party!"}
# {'total': 0, '_id': 'Comunidad de Madrid, España'}
# {'total': 1, '_id': 'Portland, OR'}
# {'total': 0, '_id': 'USA, China, New Zealand'}
# {'total': 113, '_id': 'Nebraska'}
# {'total': 0, '_id': 'Coimbatore, Bangalore, Chennai'}
# {'total': 0, '_id': 'Oregon, USA'}
# {'total': 69, '_id': 'Davis, CA'}
# {'total': 0, '_id': 'Lousada, Portugal'}
# {'total': 141, '_id': 'Online'}
# {'total': 0, '_id': 'Denver'}
# {'total': 37, '_id': 'Bay Area'}
# {'total': 0, '_id': 'New York City'}
# {'total': 0, '_id': 'Mumbai, India'}
# {'total': 0, '_id': 'United States'}
# {'total': 0, '_id': 'Bangalore'}
# {'total': 11, '_id': '日本 東京'}
# {'total': 61, '_id': 'Metro DC area, USA'}
# {'total': 161, '_id': 'Florida, USA'}
# {'total': 39, '_id': 'Arlington, VA'}
# {'total': 113, '_id': 'Mississippi'}
# {'total': 159, '_id': 'https://curiouscat.me/RedPride'}
# {'total': 30, '_id': '...'}
# {'total': 0, '_id': 'San Jose'}
# {'total': 0, '_id': 'ニューヨーク'}
# {'total': 0, '_id': '東京 杉並区'}
# {'total': 0, '_id': 'Colombia | Argentina | USA'}
# {'total': 0, '_id': '岡山 岡山市'}
# {'total': 0, '_id': 'JAPAN'}
# {'total': 117, '_id': 'Milkshake'}
# {'total': 152, '_id': 'Watertown, MA'}
# {'total': 40, '_id': 'Wisconsin, USA'}
# {'total': 9471, '_id': '⬇channel ซับเราเอง ส่องได้เด้อ'}
# {'total': 0, '_id': '東京'}
# {'total': 49, '_id': 'Bogotá, D.C., Colombia'}
# {'total': 0, '_id': 'Europe, Finland'}
# {'total': 0, '_id': '日本'}
# {'total': 0, '_id': '京都'}
# {'total': 0, '_id': 'California, USA'}
# {'total': 9468, '_id': '7 or Nothing¦ ૪ℓ ¦ ÇŸJ ¦ ĽKŁ'}
# {'total': 17, '_id': 'New York '}
# {'total': 9468, '_id': '#SPESEVENTEENTEAM'}
# {'total': 218, '_id': 'Chicago, IL'}
# {'total': 22, '_id': 'Bengaluru, India'}
# {'total': 2036, '_id': 'Purwakarta, Jawa Barat'}
# {'total': 1, '_id': 'Dallas'}
# {'total': 0, '_id': 'United Kingdom'}
# {'total': 0, '_id': 'Sheffield, England'}
# {'total': 0, '_id': 'Toledo, España'}
# {'total': 64, '_id': 'Washington DC'}
# {'total': 0, '_id': 'www.bitcoinsfuture.com'}
# {'total': 0, '_id': 'Bozeman, MT'}
# {'total': 1858, '_id': 'Florida'}
# {'total': 45, '_id': 'Cairo, Egypt'}
# {'total': 105, '_id': 'Россия'}
# {'total': 9468, '_id': 'ประเทศไทย'}
# {'total': 18, '_id': 'Mosman, Sydney'}
# {'total': 87, '_id': 'Los Angeles, CA'}
